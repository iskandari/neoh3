# %%
from neo4j import GraphDatabase
import logging
from neo4j import __version__ as neo4j_version
print(neo4j_version)
import pandas as pd
import h3
from shapely.geometry import Polygon, LineString
import json
from geojson import Feature, Point, FeatureCollection
import geopandas as gpd
# Out:
# 5.3.0

# %%
class Neo4jConnection:
    def __init__(self, uri, user, pwd):
        self.__uri = uri
        self.__user = user
        self.__pwd = pwd
        self.__driver = None
        try:
            self.__driver = GraphDatabase.driver(
                self.__uri, auth=(self.__user, self.__pwd)
            )
        except Exception as e:
            print("Failed to create the driver:", e)

    def close(self):
        if self.__driver is not None:
            self.__driver.close()

    def query(self, query, db=None):
        assert self.__driver is not None, "Driver not initialized!"
        session = None
        response = None
        try:
            session = (
                self.__driver.session(database=db)
                if db is not None
                else self.__driver.session()
            )
            response = list(session.run(query))
        except Exception as e:
            print("Query failed:", e)
        finally:
            if session is not None:
                session.close()
        return response

# %%
conn = Neo4jConnection(uri="neo4j:localhost:7474", user="neo4j", pwd="password")

# %%
## Create graph. ONLY CREATE ONCE!

query_string = f"""
CALL gds.graph.project(
'myGraph',
'H3',
'CAN_PASS',
{{
    relationshipProperties: 'cost'
}}
)
"""


conn.query(query_string)
# Out:
# Query failed: {code: Neo.ClientError.Procedure.ProcedureCallFailed} {message: Failed to invoke procedure `gds.graph.project`: Caused by: java.lang.IllegalArgumentException: A graph with name 'myGraph' already exists.}

# %%
def shortest_path(from_hex, to_hex):
    query_string = f"""

    MATCH (source:H3 {{hex_name: '{from_hex}'}}), (target:H3 {{hex_name: '{to_hex}'}})
    CALL gds.shortestPath.dijkstra.stream('myGraph', {{
    nodeLabels:['H3'],
    relationshipTypes:['CAN_PASS'],
    relationshipWeightProperty: 'cost',
    sourceNode:source,
    targetNode:target}})
    YIELD path, nodeIds
    RETURN
    [nodeId IN nodeIds | gds.util.asNode(nodeId).hex_name] AS nodeNames,
    nodes(path) as path;

    """
    res = conn.query(query_string)
    res = [record for record in res]
    return res

# %%
#Import sample ports and convert coordiantes to H3 hex ids
file = 'ports.json'

# Opening JSON file
f = open(file)
  
# returns JSON object as 
# a dictionary
data = json.load(f)
ports = [port for port in data]

def reverse(tuples):
    new_tup = tuples[::-1]
    return new_tup

def get_centroid(hex_id):
    boundary = h3.h3_to_geo_boundary(hex_id)
    boundary = [reverse(coord) for coord in boundary]
    return Polygon(boundary).centroid

# %%
#Use the first port as origin
origin = h3.geo_to_h3(data[ports[0]]['coordinates'][1], data[ports[0]]['coordinates'][0], 3)

#Calculate shortest path to all ports in JSON
routes = []
for port in ports:
    print(port)
    if 'coordinates' in data[port].keys():
        dest = h3.geo_to_h3(data[port]['coordinates'][1], data[port]['coordinates'][0], 3)
        print(dest)
        if origin != dest:
            print(origin,dest)
            hex_path = shortest_path(origin, dest)
            path = []
            if hex_path:
                for hex in hex_path[0][0]:
                    center = get_centroid(hex)
                    path.append(center)
            else:
                print('not a maritime hex id')
            routes.append({
                'geometry': LineString(path),
                'origin': origin,
                'destination': dest

            })
# Out:
# AEAJM
# 8343acfffffffff
# AEAUH
# 8343a0fffffffff
# 8343acfffffffff 8343a0fffffffff
# AEDXB
# 8343a1fffffffff
# 8343acfffffffff 8343a1fffffffff
# AEFJR
# 8343a8fffffffff
# 8343acfffffffff 8343a8fffffffff
# AEJEA
# 8343a1fffffffff
# 8343acfffffffff 8343a1fffffffff
# AEJED
# 83534dfffffffff
# 8343acfffffffff 83534dfffffffff
# AEKLF
# 8343acfffffffff
# AEPRA
# 8343acfffffffff
# AEQIW
# 8343acfffffffff
# AERKT
# 8343acfffffffff
# AERUW
# 8343a6fffffffff
# 8343acfffffffff 8343a6fffffffff
# AESHJ
# 8343acfffffffff
# AGANU
# 835e5dfffffffff
# 8343acfffffffff 835e5dfffffffff
# AGSJO
# 835e5dfffffffff
# 8343acfffffffff 835e5dfffffffff
# AIBLP
# 834d4bfffffffff
# 8343acfffffffff 834d4bfffffffff
# AIRBY
# 834d4bfffffffff
# 8343acfffffffff 834d4bfffffffff
# ALDRZ
# 831ed4fffffffff
# 8343acfffffffff 831ed4fffffffff
# ANBON
# 836744fffffffff
# 8343acfffffffff 836744fffffffff
# ANCUR
# 836746fffffffff
# 8343acfffffffff 836746fffffffff
# ANEUX
# 835e4bfffffffff
# 8343acfffffffff 835e4bfffffffff
# ANGSB
# 83e758fffffffff
# 8343acfffffffff 83e758fffffffff
# ANPHI
# 835e4bfffffffff
# 8343acfffffffff 835e4bfffffffff
# ANSXM
# 836746fffffffff
# 8343acfffffffff 836746fffffffff
# ANWIL
# 836746fffffffff
# 8343acfffffffff 836746fffffffff
# AOCAB
# 838230fffffffff
# 8343acfffffffff 838230fffffffff
# AOLAD
# 83831efffffffff
# 8343acfffffffff 83831efffffffff
# AOLOB
# 838306fffffffff
# 8343acfffffffff 838306fffffffff
# AOMSZ
# 838325fffffffff
# 8343acfffffffff 838325fffffffff
# AOSZA
# 838230fffffffff
# 8343acfffffffff 838230fffffffff
# ARBHI
# 83c350fffffffff
# 8343acfffffffff 83c350fffffffff
# ARBUE
# 83c2e3fffffffff
# 8343acfffffffff 83c2e3fffffffff
# ARCMP
# 83c2eefffffffff
# 8343acfffffffff 83c2eefffffffff
# not a maritime hex id
# ARCNQ
# 83a96efffffffff
# 8343acfffffffff 83a96efffffffff
# not a maritime hex id
# ARCRD
# 83cf9efffffffff
# 8343acfffffffff 83cf9efffffffff
# ARCVI
# 83cf91fffffffff
# 8343acfffffffff 83cf91fffffffff
# ARDDC
# 83dd68fffffffff
# 8343acfffffffff 83dd68fffffffff
# ARLPG
# 83c2e2fffffffff
# 8343acfffffffff 83c2e2fffffffff
# ARMDQ
# 83c203fffffffff
# 8343acfffffffff 83c203fffffffff
# ARNEC
# 83c205fffffffff
# 8343acfffffffff 83c205fffffffff
# AROYA
# 83a965fffffffff
# 8343acfffffffff 83a965fffffffff
# not a maritime hex id
# ARPMY
# 83c32efffffffff
# 8343acfffffffff 83c32efffffffff
# ARPUD
# 83cf94fffffffff
# 8343acfffffffff 83cf94fffffffff
# ARRGA
# 83df6afffffffff
# 8343acfffffffff 83df6afffffffff
# ARRGL
# 83cfa4fffffffff
# 8343acfffffffff 83cfa4fffffffff
# ARRIC
# 83df6bfffffffff
# 8343acfffffffff 83df6bfffffffff
# ARROS
# 83c2ebfffffffff
# 8343acfffffffff 83c2ebfffffffff
# not a maritime hex id
# ARSAE
# 83c32bfffffffff
# 8343acfffffffff 83c32bfffffffff
# ARSFN
# 83b24dfffffffff
# 8343acfffffffff 83b24dfffffffff
# not a maritime hex id
# ARSLO
# 83c2ebfffffffff
# 8343acfffffffff 83c2ebfffffffff
# not a maritime hex id
# ARSNS
# 83c2e8fffffffff
# 8343acfffffffff 83c2e8fffffffff
# not a maritime hex id
# ARSPD
# 83c2eefffffffff
# 8343acfffffffff 83c2eefffffffff
# not a maritime hex id
# ARUSH
# 83df45fffffffff
# 8343acfffffffff 83df45fffffffff
# ARZAE
# 83c2eefffffffff
# 8343acfffffffff 83c2eefffffffff
# not a maritime hex id
# ASPPG
# 839a14fffffffff
# 8343acfffffffff 839a14fffffffff
# ATLTX
# 831e15fffffffff
# 8343acfffffffff 831e15fffffffff
# not a maritime hex id
# AUABP
# 839d0efffffffff
# 8343acfffffffff 839d0efffffffff
# AUADL
# 83b916fffffffff
# 8343acfffffffff 83b916fffffffff
# AUARD
# 83b916fffffffff
# 8343acfffffffff 83b916fffffffff
# AUBBY
# 83c9b0fffffffff
# 8343acfffffffff 83c9b0fffffffff
# AUBEL
# 83bf4afffffffff
# 8343acfffffffff 83bf4afffffffff
# AUBNE
# 83be8dfffffffff
# 8343acfffffffff 83be8dfffffffff
# AUBOO
# 839ce2fffffffff
# 8343acfffffffff 839ce2fffffffff
# AUBWT
# 83bf4bfffffffff
# 8343acfffffffff 83bf4bfffffffff
# AUCHT
# 83a735fffffffff
# 8343acfffffffff 83a735fffffffff
# not a maritime hex id
# AUCNS
# 839c23fffffffff
# 8343acfffffffff 839c23fffffffff
# AUDPO
# 83bf4bfffffffff
# 8343acfffffffff 83bf4bfffffffff
# AUDRW
# 839450fffffffff
# 8343acfffffffff 839450fffffffff
# AUFRE
# 83a726fffffffff
# 8343acfffffffff 83a726fffffffff
# AUGLT
# 839d21fffffffff
# 8343acfffffffff 839d21fffffffff
# AUGOV
# 839451fffffffff
# 8343acfffffffff 839451fffffffff
# AUHBA
# 83bf4cfffffffff
# 8343acfffffffff 83bf4cfffffffff
# AUHPT
# 839d01fffffffff
# 8343acfffffffff 839d01fffffffff
# AULST
# 83bf48fffffffff
# 8343acfffffffff 83bf48fffffffff
# AUMEL
# 83be63fffffffff
# 8343acfffffffff 83be63fffffffff
# AUNLK
# 83bf4dfffffffff
# 8343acfffffffff 83bf4dfffffffff
# AUNTL
# 83be1dfffffffff
# 8343acfffffffff 83be1dfffffffff
# AUPAE
# 83b916fffffffff
# 8343acfffffffff 83b916fffffffff
# AUPHE
# 83a79afffffffff
# 8343acfffffffff 83a79afffffffff
# AUPKL
# 83be08fffffffff
# 8343acfffffffff 83be08fffffffff
# AUSYD
# 83be0efffffffff
# 8343acfffffffff 83be0efffffffff
# AUTSV
# 839d0bfffffffff
# 8343acfffffffff 839d0bfffffffff
# AUWEI
# 839ce4fffffffff
# 8343acfffffffff 839ce4fffffffff
# AWAUA
# 836773fffffffff
# 8343acfffffffff 836773fffffffff
# AWORJ
# 836773fffffffff
# 8343acfffffffff 836773fffffffff
# AZBAK
# 832ce5fffffffff
# 8343acfffffffff 832ce5fffffffff
# not a maritime hex id
# BBBGI
# 835e70fffffffff
# 8343acfffffffff 835e70fffffffff
# BDCGP
# 833cc2fffffffff
# 8343acfffffffff 833cc2fffffffff
# BDCHL
# 833cf3fffffffff
# 8343acfffffffff 833cf3fffffffff
# BDDAC
# 833cf1fffffffff
# 8343acfffffffff 833cf1fffffffff
# BDMGL
# 833cf3fffffffff
# 8343acfffffffff 833cf3fffffffff
# BEANR
# 831fa4fffffffff
# 8343acfffffffff 831fa4fffffffff
# BEBSU
# 83194dfffffffff
# 8343acfffffffff 83194dfffffffff
# BEDEL
# 831fa4fffffffff
# 8343acfffffffff 831fa4fffffffff
# BEGNE
# 83194dfffffffff
# 8343acfffffffff 83194dfffffffff
# BEOST
# 83194dfffffffff
# 8343acfffffffff 83194dfffffffff
# BEZEE
# 83194dfffffffff
# 8343acfffffffff 83194dfffffffff
# BFOUA
# 835991fffffffff
# 8343acfffffffff 835991fffffffff
# not a maritime hex id
# BGBOJ
# 831eebfffffffff
# 8343acfffffffff 831eebfffffffff
# BGVAR
# 831eebfffffffff
# 8343acfffffffff 831eebfffffffff
# BHAHD
# BHBAH
# 83536efffffffff
# 8343acfffffffff 83536efffffffff
# BHKBS
# 83536efffffffff
# 8343acfffffffff 83536efffffffff
# BHMAN
# 83536efffffffff
# 8343acfffffffff 83536efffffffff
# BHSIT
# 83536efffffffff
# 8343acfffffffff 83536efffffffff
# BJCOO
# 835891fffffffff
# 8343acfffffffff 835891fffffffff
# BMBDA
# 832a4cfffffffff
# 8343acfffffffff 832a4cfffffffff
# BMSOU
# 831959fffffffff
# 8343acfffffffff 831959fffffffff
# BNBWN
# 836816fffffffff
# 8343acfffffffff 836816fffffffff
# BNKUB
# 8368a5fffffffff
# 8343acfffffffff 8368a5fffffffff
# BNMUA
# 836810fffffffff
# 8343acfffffffff 836810fffffffff
# BOPBU
# 83a845fffffffff
# 8343acfffffffff 83a845fffffffff
# not a maritime hex id
# BOSRZ
# 838b22fffffffff
# 8343acfffffffff 838b22fffffffff
# not a maritime hex id
# BRARB
# 838116fffffffff
# 8343acfffffffff 838116fffffffff
# BRARE
# 83818bfffffffff
# 8343acfffffffff 83818bfffffffff
# BRBEL
# 838044fffffffff
# 8343acfffffffff 838044fffffffff
# BRCDO
# 838183fffffffff
# 8343acfffffffff 838183fffffffff
# BRFNO
# 83a8a2fffffffff
# 8343acfffffffff 83a8a2fffffffff
# BRFOR
# 838010fffffffff
# 8343acfffffffff 838010fffffffff
# BRIBB
# 83a918fffffffff
# 8343acfffffffff 83a918fffffffff
# BRIGI
# 83a8a0fffffffff
# 8343acfffffffff 83a8a0fffffffff
# BRIOA
# 83a831fffffffff
# 8343acfffffffff 83a831fffffffff
# BRIOS
# 838132fffffffff
# 8343acfffffffff 838132fffffffff
# BRIRO
# 83a881fffffffff
# 8343acfffffffff 83a881fffffffff
# not a maritime hex id
# BRITJ
# 83a835fffffffff
# 8343acfffffffff 83a835fffffffff
# BRITQ
# 83a975fffffffff
# 8343acfffffffff 83a975fffffffff
# not a maritime hex id
# BRITZ
# 83a886fffffffff
# 8343acfffffffff 83a886fffffffff
# BRMAO
# 838af6fffffffff
# 8343acfffffffff 838af6fffffffff
# not a maritime hex id
# BRMCZ
# 838185fffffffff
# 8343acfffffffff 838185fffffffff
# BRNAT
# 838199fffffffff
# 8343acfffffffff 838199fffffffff
# BRNVT
# 83a835fffffffff
# 8343acfffffffff 83a835fffffffff
# BRPCL
# 83a891fffffffff
# 8343acfffffffff 83a891fffffffff
# BRPEC
# 838010fffffffff
# 8343acfffffffff 838010fffffffff
# BRPNG
# 83a831fffffffff
# 8343acfffffffff 83a831fffffffff
# BRPNN
# 83a8dbfffffffff
# 8343acfffffffff 83a8dbfffffffff
# not a maritime hex id
# BRPOA
# 83a901fffffffff
# 8343acfffffffff 83a901fffffffff
# BRREC
# 838183fffffffff
# 8343acfffffffff 838183fffffffff
# BRRIG
# 83a92efffffffff
# 8343acfffffffff 83a92efffffffff
# BRRIO
# 83a8a0fffffffff
# 8343acfffffffff 83a8a0fffffffff
# BRSAL
# 83a803fffffffff
# 8343acfffffffff 83a803fffffffff
# not a maritime hex id
# BRSFS
# 83a835fffffffff
# 8343acfffffffff 83a835fffffffff
# BRSPB
# 83a8a0fffffffff
# 8343acfffffffff 83a8a0fffffffff
# BRSSA
# 838116fffffffff
# 8343acfffffffff 838116fffffffff
# BRSSO
# 83a816fffffffff
# 8343acfffffffff 83a816fffffffff
# BRSSZ
# 83a810fffffffff
# 8343acfffffffff 83a810fffffffff
# BRSTM
# 838a9cfffffffff
# 8343acfffffffff 838a9cfffffffff
# not a maritime hex id
# BRSUA
# 838180fffffffff
# 8343acfffffffff 838180fffffffff
# BRVDC
# 838131fffffffff
# 8343acfffffffff 838131fffffffff
# not a maritime hex id
# BRVIC
# 838183fffffffff
# 8343acfffffffff 838183fffffffff
# BRVIX
# 83a895fffffffff
# 8343acfffffffff 83a895fffffffff
# BRVLC
# 838044fffffffff
# 8343acfffffffff 838044fffffffff
# BSFPO
# 8344a3fffffffff
# 8343acfffffffff 8344a3fffffffff
# BSNAS
# 8344b5fffffffff
# 8343acfffffffff 8344b5fffffffff
# BYMSQ
# 831f4efffffffff
# 8343acfffffffff 831f4efffffffff
# not a maritime hex id
# BZBZE
# 834505fffffffff
# 8343acfffffffff 834505fffffffff
# CABAT
# 832b15fffffffff
# 8343acfffffffff 832b15fffffffff
# CABCK
# 832b8efffffffff
# 8343acfffffffff 832b8efffffffff
# not a maritime hex id
# CABDU
# 832baafffffffff
# 8343acfffffffff 832baafffffffff
# not a maritime hex id
# CABEC
# 832baefffffffff
# 8343acfffffffff 832baefffffffff
# not a maritime hex id
# CABJO
# 832b34fffffffff
# 8343acfffffffff 832b34fffffffff
# CABRL
# 832b9bfffffffff
# 8343acfffffffff 832b9bfffffffff
# not a maritime hex id
# CACAL
# 8312ccfffffffff
# 8343acfffffffff 8312ccfffffffff
# not a maritime hex id
# CACBK
# 831b9afffffffff
# 8343acfffffffff 831b9afffffffff
# CACCB
# 8328dcfffffffff
# 8343acfffffffff 8328dcfffffffff
# CACOL
# 832b9afffffffff
# 8343acfffffffff 832b9afffffffff
# not a maritime hex id
# CACRO
# 8328dcfffffffff
# 8343acfffffffff 8328dcfffffffff
# CACWL
# 832b81fffffffff
# 8343acfffffffff 832b81fffffffff
# not a maritime hex id
# CADOR
# 832baafffffffff
# 8343acfffffffff 832baafffffffff
# not a maritime hex id
# CADRU
# 832baafffffffff
# 8343acfffffffff 832baafffffffff
# not a maritime hex id
# CAEDM
# 8312ecfffffffff
# 8343acfffffffff 8312ecfffffffff
# not a maritime hex id
# CAHAL
# 832b0cfffffffff
# 8343acfffffffff 832b0cfffffffff
# CAHAM
# 832b9bfffffffff
# 8343acfffffffff 832b9bfffffffff
# not a maritime hex id
# CAHMC
# 8328dcfffffffff
# 8343acfffffffff 8328dcfffffffff
# CAKVL
# 832ab2fffffffff
# 8343acfffffffff 832ab2fffffffff
# not a maritime hex id
# CAMAG
# 832ba8fffffffff
# 8343acfffffffff 832ba8fffffffff
# not a maritime hex id
# CAMNT
# 832b00fffffffff
# 8343acfffffffff 832b00fffffffff
# CAMTR
# 832baafffffffff
# 8343acfffffffff 832baafffffffff
# not a maritime hex id
# CANIA
# 832b9bfffffffff
# 8343acfffffffff 832b9bfffffffff
# not a maritime hex id
# CANNO
# 8328dcfffffffff
# 8343acfffffffff 8328dcfffffffff
# CANOR
# 832b91fffffffff
# 8343acfffffffff 832b91fffffffff
# not a maritime hex id
# CANWE
# 8328defffffffff
# 8343acfffffffff 8328defffffffff
# CAOAK
# 832b9bfffffffff
# 8343acfffffffff 832b9bfffffffff
# not a maritime hex id
# CAODE
# 832b9dfffffffff
# 8343acfffffffff 832b9dfffffffff
# not a maritime hex id
# CAOSH
# 832b98fffffffff
# 8343acfffffffff 832b98fffffffff
# not a maritime hex id
# CAPCR
# 832b9bfffffffff
# 8343acfffffffff 832b9bfffffffff
# not a maritime hex id
# CAPDV
# 832ab5fffffffff
# 8343acfffffffff 832ab5fffffffff
# not a maritime hex id
# CAPML
# 8328defffffffff
# 8343acfffffffff 8328defffffffff
# CAPOI
# 832baafffffffff
# 8343acfffffffff 832baafffffffff
# not a maritime hex id
# CAPRR
# 831286fffffffff
# 8343acfffffffff 831286fffffffff
# CAQUE
# 832bacfffffffff
# 8343acfffffffff 832bacfffffffff
# CASAK
# 831259fffffffff
# 8343acfffffffff 831259fffffffff
# not a maritime hex id
# CASCA
# 832b9bfffffffff
# 8343acfffffffff 832b9bfffffffff
# not a maritime hex id
# CASJB
# 832b1cfffffffff
# 8343acfffffffff 832b1cfffffffff
# CASJF
# 831aa0fffffffff
# 8343acfffffffff 831aa0fffffffff
# CASNI
# 832ab6fffffffff
# 8343acfffffffff 832ab6fffffffff
# not a maritime hex id
# CASOR
# 832baafffffffff
# 8343acfffffffff 832baafffffffff
# not a maritime hex id
# CASSM
# 832763fffffffff
# 8343acfffffffff 832763fffffffff
# not a maritime hex id
# CASTC
# 832b9bfffffffff
# 8343acfffffffff 832b9bfffffffff
# not a maritime hex id
# CASUM
# 832b00fffffffff
# 8343acfffffffff 832b00fffffffff
# CATEX
# 8328d8fffffffff
# 8343acfffffffff 8328d8fffffffff
# CATHU
# 832770fffffffff
# 8343acfffffffff 832770fffffffff
# not a maritime hex id
# CATOR
# 832b9bfffffffff
# 8343acfffffffff 832b9bfffffffff
# not a maritime hex id
# CATRR
# 832baefffffffff
# 8343acfffffffff 832baefffffffff
# not a maritime hex id
# CATTC
# 832b9dfffffffff
# 8343acfffffffff 832b9dfffffffff
# not a maritime hex id
# CAVAN
# 8328defffffffff
# 8343acfffffffff 8328defffffffff
# CAVLF
# 832b81fffffffff
# 8343acfffffffff 832b81fffffffff
# not a maritime hex id
# CAWIN
# 832b9bfffffffff
# 8343acfffffffff 832b9bfffffffff
# not a maritime hex id
# CAWNP
# 83271cfffffffff
# 8343acfffffffff 83271cfffffffff
# not a maritime hex id
# CDBOA
# 83546efffffffff
# 8343acfffffffff 83546efffffffff
# not a maritime hex id
# CDMAT
# 835461fffffffff
# 8343acfffffffff 835461fffffffff
# not a maritime hex id
# CGPNR
# 838233fffffffff
# 8343acfffffffff 838233fffffffff
# CIABJ
# 837519fffffffff
# 8343acfffffffff 837519fffffffff
# CISPY
# 837436fffffffff
# 8343acfffffffff 837436fffffffff
# CLANF
# 83b226fffffffff
# 8343acfffffffff 83b226fffffffff
# CLARI
# 83b304fffffffff
# 8343acfffffffff 83b304fffffffff
# CLBAG
# 83df69fffffffff
# 8343acfffffffff 83df69fffffffff
# CLBAR
# 83b200fffffffff
# 8343acfffffffff 83b200fffffffff
# CLCAP
# 83392dfffffffff
# 8343acfffffffff 83392dfffffffff
# CLCBC
# 83ceaefffffffff
# 8343acfffffffff 83ceaefffffffff
# CLCCL
# 83b304fffffffff
# 8343acfffffffff 83b304fffffffff
# CLCHB
# 83cf8bfffffffff
# 8343acfffffffff 83cf8bfffffffff
# CLCLD
# 83b200fffffffff
# 8343acfffffffff 83b200fffffffff
# CLCNL
# 83b2dbfffffffff
# 8343acfffffffff 83b2dbfffffffff
# CLCNR
# 83b200fffffffff
# 8343acfffffffff 83b200fffffffff
# CLCNX
# 83df69fffffffff
# 8343acfffffffff 83df69fffffffff
# CLCQQ
# 83b219fffffffff
# 8343acfffffffff 83b219fffffffff
# CLCRR
# 83ce8cfffffffff
# 8343acfffffffff 83ce8cfffffffff
# CLDCH
# 83ceacfffffffff
# 8343acfffffffff 83ceacfffffffff
# CLGYC
# 83b219fffffffff
# 8343acfffffffff 83b219fffffffff
# CLHSO
# 83b21dfffffffff
# 8343acfffffffff 83b21dfffffffff
# CLIPC
# 83b0a2fffffffff
# 8343acfffffffff 83b0a2fffffffff
# CLIQQ
# 83b303fffffffff
# 8343acfffffffff 83b303fffffffff
# CLJRL
# 83ee0efffffffff
# 8343acfffffffff 83ee0efffffffff
# CLLOS
# 83b2e2fffffffff
# 8343acfffffffff 83b2e2fffffffff
# CLLQN
# 83b2d8fffffffff
# 8343acfffffffff 83b2d8fffffffff
# CLLVS
# 83b2c4fffffffff
# 8343acfffffffff 83b2c4fffffffff
# CLMCH
# 83b319fffffffff
# 8343acfffffffff 83b319fffffffff
# CLMJS
# 83b226fffffffff
# 8343acfffffffff 83b226fffffffff
# CLPAG
# 83b226fffffffff
# 8343acfffffffff 83b226fffffffff
# CLPCH
# 83cf8bfffffffff
# 8343acfffffffff 83cf8bfffffffff
# CLPEO
# 83b2d8fffffffff
# 8343acfffffffff 83b2d8fffffffff
# CLPGO
# 83ee19fffffffff
# 8343acfffffffff 83ee19fffffffff
# CLPMC
# 83ceaafffffffff
# 8343acfffffffff 83ceaafffffffff
# CLPNT
# 83cf12fffffffff
# 8343acfffffffff 83cf12fffffffff
# CLPPC
# 83b303fffffffff
# 8343acfffffffff 83b303fffffffff
# CLPPD
# 83eef4fffffffff
# 8343acfffffffff 83eef4fffffffff
# CLPTE
# 83ceacfffffffff
# 8343acfffffffff 83ceacfffffffff
# CLPTI
# 83b303fffffffff
# 8343acfffffffff 83b303fffffffff
# CLPUQ
# 83df69fffffffff
# 8343acfffffffff 83df69fffffffff
# CLQMC
# 83ceaefffffffff
# 8343acfffffffff 83ceaefffffffff
# CLQTV
# 83b2c4fffffffff
# 8343acfffffffff 83b2c4fffffffff
# CLSAI
# 83b2c0fffffffff
# 8343acfffffffff 83b2c0fffffffff
# CLSVE
# 83b2d8fffffffff
# 8343acfffffffff 83b2d8fffffffff
# CLTAL
# 83b2d8fffffffff
# 8343acfffffffff 83b2d8fffffffff
# CLTHO
# 83b2d8fffffffff
# 8343acfffffffff 83b2d8fffffffff
# CLTOM
# 83b2d8fffffffff
# 8343acfffffffff 83b2d8fffffffff
# CLTOQ
# 83b319fffffffff
# 8343acfffffffff 83b319fffffffff
# CLTTC
# 83b204fffffffff
# 8343acfffffffff 83b204fffffffff
# CLVAP
# 83b2c4fffffffff
# 8343acfffffffff 83b2c4fffffffff
# CLWCA
# 83ceacfffffffff
# 8343acfffffffff 83ceacfffffffff
# CLWCH
# 83cea1fffffffff
# 8343acfffffffff 83cea1fffffffff
# CLWPA
# 83cf8bfffffffff
# 8343acfffffffff 83cf8bfffffffff
# CLWPU
# 83df45fffffffff
# 8343acfffffffff 83df45fffffffff
# CLZUD
# 83cea8fffffffff
# 8343acfffffffff 83cea8fffffffff
# CMDLA
# 8382d2fffffffff
# 8343acfffffffff 8382d2fffffffff
# CNBAY
# 833004fffffffff
# 8343acfffffffff 833004fffffffff
# CNBHY
# 834152fffffffff
# 8343acfffffffff 834152fffffffff
# not a maritime hex id
# CNBJO
# 8341b5fffffffff
# 8343acfffffffff 8341b5fffffffff
# CNCAN
# 834118fffffffff
# 8343acfffffffff 834118fffffffff
# CNCGU
# 833098fffffffff
# 8343acfffffffff 833098fffffffff
# CNCKG
# 834019fffffffff
# 8343acfffffffff 834019fffffffff
# not a maritime hex id
# CNCOZ
# 834112fffffffff
# 8343acfffffffff 834112fffffffff
# CNCSX
# 834189fffffffff
# 8343acfffffffff 834189fffffffff
# not a maritime hex id
# CNCTU
# 8340e3fffffffff
# 8343acfffffffff 8340e3fffffffff
# not a maritime hex id
# CNCWN
# 83411cfffffffff
# 8343acfffffffff 83411cfffffffff
# CNDAA
# 833083fffffffff
# 8343acfffffffff 833083fffffffff
# CNDAL
# 833006fffffffff
# 8343acfffffffff 833006fffffffff
# CNDCB
# CNDGG
# 83411cfffffffff
# 8343acfffffffff 83411cfffffffff
# CNDLC
# 833006fffffffff
# 8343acfffffffff 833006fffffffff
# CNDOU
# 83411dfffffffff
# 8343acfffffffff 83411dfffffffff
# CNFAN
# 834150fffffffff
# 8343acfffffffff 834150fffffffff
# CNFNG
# 83411cfffffffff
# 8343acfffffffff 83411cfffffffff
# CNFOC
# CNFOS
# 83411dfffffffff
# 8343acfffffffff 83411dfffffffff
# CNFUG
# 8341b5fffffffff
# 8343acfffffffff 8341b5fffffffff
# CNGGY
# 834118fffffffff
# 8343acfffffffff 834118fffffffff
# CNGOG
# 83411cfffffffff
# 8343acfffffffff 83411cfffffffff
# CNGOM
# 83411dfffffffff
# 8343acfffffffff 83411dfffffffff
# CNGUG
# 834025fffffffff
# 8343acfffffffff 834025fffffffff
# not a maritime hex id
# CNHAK
# 834172fffffffff
# 8343acfffffffff 834172fffffffff
# CNHDU
# 834118fffffffff
# 8343acfffffffff 834118fffffffff
# CNHEB
# 833185fffffffff
# 8343acfffffffff 833185fffffffff
# not a maritime hex id
# CNHGH
# 83309afffffffff
# 8343acfffffffff 83309afffffffff
# CNHME
# 83309dfffffffff
# 8343acfffffffff 83309dfffffffff
# CNHMN
# 83411cfffffffff
# 8343acfffffffff 83411cfffffffff
# CNHSN
# 83411dfffffffff
# 8343acfffffffff 83411dfffffffff
# CNHUA
# 834118fffffffff
# 8343acfffffffff 834118fffffffff
# CNHUD
# 833035fffffffff
# 8343acfffffffff 833035fffffffff
# CNHUI
# 83411cfffffffff
# 8343acfffffffff 83411cfffffffff
# CNJGZ
# 8340a1fffffffff
# 8343acfffffffff 8340a1fffffffff
# not a maritime hex id
# CNJIA
# 83309cfffffffff
# 8343acfffffffff 83309cfffffffff
# CNJIN
# 83418cfffffffff
# 8343acfffffffff 83418cfffffffff
# not a maritime hex id
# CNJIU
# 83419dfffffffff
# 8343acfffffffff 83419dfffffffff
# not a maritime hex id
# CNJMN
# 83411dfffffffff
# 8343acfffffffff 83411dfffffffff
# CNJNZ
# 833026fffffffff
# 8343acfffffffff 833026fffffffff
# not a maritime hex id
# CNJXN
# 83411dfffffffff
# 8343acfffffffff 83411dfffffffff
# CNJZU
# 8341acfffffffff
# 8343acfffffffff 8341acfffffffff
# not a maritime hex id
# CNKHN
# 834183fffffffff
# 8343acfffffffff 834183fffffffff
# not a maritime hex id
# CNKMG
# 834071fffffffff
# 8343acfffffffff 834071fffffffff
# not a maritime hex id
# CNKPN
# 83318dfffffffff
# 8343acfffffffff 83318dfffffffff
# CNLAN
# 83411cfffffffff
# 8343acfffffffff 83411cfffffffff
# CNLGH
# 83411cfffffffff
# 8343acfffffffff 83411cfffffffff
# CNLIH
# 834111fffffffff
# 8343acfffffffff 834111fffffffff
# CNLKU
# 833010fffffffff
# 8343acfffffffff 833010fffffffff
# CNLSI
# 834036fffffffff
# 8343acfffffffff 834036fffffffff
# not a maritime hex id
# CNLYG
# 833084fffffffff
# 8343acfffffffff 833084fffffffff
# CNLZH
# 834152fffffffff
# 8343acfffffffff 834152fffffffff
# not a maritime hex id
# CNMAW
# 8341b5fffffffff
# 8343acfffffffff 8341b5fffffffff
# CNMMI
# 834109fffffffff
# 8343acfffffffff 834109fffffffff
# CNMWN
# 83411cfffffffff
# 8343acfffffffff 83411cfffffffff
# CNMYG
# 8340c4fffffffff
# 8343acfffffffff 8340c4fffffffff
# not a maritime hex id
# CNNAH
# 83411dfffffffff
# 8343acfffffffff 83411dfffffffff
# CNNBO
# 834b34fffffffff
# 8343acfffffffff 834b34fffffffff
# CNNGB
# 834b34fffffffff
# 8343acfffffffff 834b34fffffffff
# CNNGG
# 83411dfffffffff
# 8343acfffffffff 83411dfffffffff
# CNNKG
# 833091fffffffff
# 8343acfffffffff 833091fffffffff
# not a maritime hex id
# CNNNG
# 834152fffffffff
# 8343acfffffffff 834152fffffffff
# not a maritime hex id
# CNNSA
# 83411dfffffffff
# 8343acfffffffff 83411dfffffffff
# CNNTG
# 83309dfffffffff
# 8343acfffffffff 83309dfffffffff
# CNPNY
# 83411dfffffffff
# 8343acfffffffff 83411dfffffffff
# CNPUT
# 8341a4fffffffff
# 8343acfffffffff 8341a4fffffffff
# CNQAW
# 8330a1fffffffff
# 8343acfffffffff 8330a1fffffffff
# CNQIN
# 8330acfffffffff
# 8343acfffffffff 8330acfffffffff
# CNQYN
# 834118fffffffff
# 8343acfffffffff 834118fffffffff
# CNQZJ
# 8341a0fffffffff
# 8343acfffffffff 8341a0fffffffff
# CNROQ
# 83411dfffffffff
# 8343acfffffffff 83411dfffffffff
# CNRZH
# 8330a3fffffffff
# 8343acfffffffff 8330a3fffffffff
# CNSBU
# 83411dfffffffff
# 8343acfffffffff 83411dfffffffff
# CNSDG
# 834109fffffffff
# 8343acfffffffff 834109fffffffff
# CNSGH
# 833099fffffffff
# 8343acfffffffff 833099fffffffff
# CNSHA
# 833099fffffffff
# 8343acfffffffff 833099fffffffff
# CNSHK
# 83411cfffffffff
# 8343acfffffffff 83411cfffffffff
# CNSHP
# 833030fffffffff
# 8343acfffffffff 833030fffffffff
# CNSIN
# 83411dfffffffff
# 8343acfffffffff 83411dfffffffff
# CNSJQ
# 834119fffffffff
# 8343acfffffffff 834119fffffffff
# not a maritime hex id
# CNSNW
# 83411dfffffffff
# 8343acfffffffff 83411dfffffffff
# CNSSH
# 83411dfffffffff
# 8343acfffffffff 83411dfffffffff
# CNSTG
# CNSUD
# 83411dfffffffff
# 8343acfffffffff 83411dfffffffff
# CNSWA
# 834118fffffffff
# 8343acfffffffff 834118fffffffff
# CNSWE
# 834111fffffffff
# 8343acfffffffff 834111fffffffff
# CNSZX
# 83411cfffffffff
# 8343acfffffffff 83411cfffffffff
# CNTAG
# 833098fffffffff
# 8343acfffffffff 833098fffffffff
# CNTAO
# 8330acfffffffff
# 8343acfffffffff 8330acfffffffff
# CNTAP
# 834109fffffffff
# 8343acfffffffff 834109fffffffff
# CNTHG
# 83411dfffffffff
# 8343acfffffffff 83411dfffffffff
# CNTSN
# 83318cfffffffff
# 8343acfffffffff 83318cfffffffff
# not a maritime hex id
# CNTXG
# 83318dfffffffff
# 8343acfffffffff 83318dfffffffff
# CNTZO
# 83309cfffffffff
# 8343acfffffffff 83309cfffffffff
# CNWAZ
# 834103fffffffff
# 8343acfffffffff 834103fffffffff
# CNWEI
# 833011fffffffff
# 8343acfffffffff 833011fffffffff
# CNWHI
# 833093fffffffff
# 8343acfffffffff 833093fffffffff
# not a maritime hex id
# CNWNZ
# 8341b2fffffffff
# 8343acfffffffff 8341b2fffffffff
# CNWUH
# 8340a6fffffffff
# 8343acfffffffff 8340a6fffffffff
# not a maritime hex id
# CNXAB
# 83411efffffffff
# 8343acfffffffff 83411efffffffff
# not a maritime hex id
# CNXAM
# 8341a5fffffffff
# 8343acfffffffff 8341a5fffffffff
# CNXGA
# 83318dfffffffff
# 8343acfffffffff 83318dfffffffff
# CNXGG
# 83318dfffffffff
# 8343acfffffffff 83318dfffffffff
# CNXIL
# 83411dfffffffff
# 8343acfffffffff 83411dfffffffff
# CNXIN
# 83411dfffffffff
# 8343acfffffffff 83411dfffffffff
# CNXIT
# 834118fffffffff
# 8343acfffffffff 834118fffffffff
# CNXMN
# 8341a5fffffffff
# 8343acfffffffff 8341a5fffffffff
# CNYAN
# 834b30fffffffff
# 8343acfffffffff 834b30fffffffff
# CNYIC
# 8340a1fffffffff
# 8343acfffffffff 8340a1fffffffff
# not a maritime hex id
# CNYIK
# 833022fffffffff
# 8343acfffffffff 833022fffffffff
# CNYJI
# 834108fffffffff
# 8343acfffffffff 834108fffffffff
# CNYNF
# 83410afffffffff
# 8343acfffffffff 83410afffffffff
# CNYNT
# 833011fffffffff
# 8343acfffffffff 833011fffffffff
# CNYPG
# 834173fffffffff
# 8343acfffffffff 834173fffffffff
# CNYQS
# 83411dfffffffff
# 8343acfffffffff 83411dfffffffff
# CNYTG
# 833011fffffffff
# 8343acfffffffff 833011fffffffff
# CNYTN
# 8341b0fffffffff
# 8343acfffffffff 8341b0fffffffff
# CNYZH
# 833091fffffffff
# 8343acfffffffff 833091fffffffff
# not a maritime hex id
# CNZAP
# 83309bfffffffff
# 8343acfffffffff 83309bfffffffff
# CNZHA
# 834118fffffffff
# 8343acfffffffff 834118fffffffff
# CNZHE
# 833091fffffffff
# 8343acfffffffff 833091fffffffff
# not a maritime hex id
# CNZJG
# 83309cfffffffff
# 8343acfffffffff 83309cfffffffff
# CNZOS
# 834b35fffffffff
# 8343acfffffffff 834b35fffffffff
# CNZQG
# 834119fffffffff
# 8343acfffffffff 834119fffffffff
# not a maritime hex id
# CNZSN
# 83411dfffffffff
# 8343acfffffffff 83411dfffffffff
# CNZUH
# 83411dfffffffff
# 8343acfffffffff 83411dfffffffff
# COBAQ
# 836622fffffffff
# 8343acfffffffff 836622fffffffff
# COBUN
# 8366f0fffffffff
# 8343acfffffffff 8366f0fffffffff
# COCTG
# 836631fffffffff
# 8343acfffffffff 836631fffffffff
# COPBO
# 836622fffffffff
# 8343acfffffffff 836622fffffffff
# COSMR
# 836622fffffffff
# 8343acfffffffff 836622fffffffff
# COTCO
# 8366d0fffffffff
# 8343acfffffffff 8366d0fffffffff
# CRCAL
# 836d69fffffffff
# 8343acfffffffff 836d69fffffffff
# CRGLF
# 8366b5fffffffff
# 8343acfffffffff 8366b5fffffffff
# CRLIO
# 83679bfffffffff
# 8343acfffffffff 83679bfffffffff
# CRMOB
# 83679bfffffffff
# 8343acfffffffff 83679bfffffffff
# CRPAS
# 836d69fffffffff
# 8343acfffffffff 836d69fffffffff
# CRPCA
# 836d69fffffffff
# 8343acfffffffff 836d69fffffffff
# CRSJO
# 836d69fffffffff
# 8343acfffffffff 836d69fffffffff
# CUHAV
# 834432fffffffff
# 8343acfffffffff 834432fffffffff
# CUMAR
# 834432fffffffff
# 8343acfffffffff 834432fffffffff
# CUQMA
# 834588fffffffff
# 8343acfffffffff 834588fffffffff
# CUSCU
# 834c9afffffffff
# 8343acfffffffff 834c9afffffffff
# CVMIN
# 83574cfffffffff
# 8343acfffffffff 83574cfffffffff
# CVPAL
# 8354b6fffffffff
# 8343acfffffffff 8354b6fffffffff
# CVRAI
# 835494fffffffff
# 8343acfffffffff 835494fffffffff
# CYLMS
# 833f4dfffffffff
# 8343acfffffffff 833f4dfffffffff
# CYNIC
# 832da4fffffffff
# 8343acfffffffff 832da4fffffffff
# CYPFO
# 833f4dfffffffff
# 8343acfffffffff 833f4dfffffffff
# DEBEZ
# 831f81fffffffff
# 8343acfffffffff 831f81fffffffff
# not a maritime hex id
# DEBIN
# 831faefffffffff
# 8343acfffffffff 831faefffffffff
# not a maritime hex id
# DEBKE
# 831f14fffffffff
# 8343acfffffffff 831f14fffffffff
# DEBOY
# 831f10fffffffff
# 8343acfffffffff 831f10fffffffff
# not a maritime hex id
# DEBRA
# 831f15fffffffff
# 8343acfffffffff 831f15fffffffff
# DEBRB
# 831f33fffffffff
# 8343acfffffffff 831f33fffffffff
# DEBRE
# 831f15fffffffff
# 8343acfffffffff 831f15fffffffff
# DEBRV
# 831f15fffffffff
# 8343acfffffffff 831f15fffffffff
# DEBSK
# 831f00fffffffff
# 8343acfffffffff 831f00fffffffff
# DECGN
# 831fa1fffffffff
# 8343acfffffffff 831fa1fffffffff
# not a maritime hex id
# DECUX
# 831f33fffffffff
# 8343acfffffffff 831f33fffffffff
# DEDUS
# 831fa5fffffffff
# 8343acfffffffff 831fa5fffffffff
# not a maritime hex id
# DEELS
# 831f14fffffffff
# 8343acfffffffff 831f14fffffffff
# DEEME
# 831f14fffffffff
# 8343acfffffffff 831f14fffffffff
# DEFLF
# 831f31fffffffff
# 8343acfffffffff 831f31fffffffff
# DEHAM
# 831f15fffffffff
# 8343acfffffffff 831f15fffffffff
# DEHBU
# 831f15fffffffff
# 8343acfffffffff 831f15fffffffff
# DEHMM
# 831f12fffffffff
# 8343acfffffffff 831f12fffffffff
# not a maritime hex id
# DEKEL
# 831f06fffffffff
# 8343acfffffffff 831f06fffffffff
# DEKGU
# 831fabfffffffff
# 8343acfffffffff 831fabfffffffff
# not a maritime hex id
# DEKHO
# 831faafffffffff
# 8343acfffffffff 831faafffffffff
# not a maritime hex id
# DELBC
# 831f02fffffffff
# 8343acfffffffff 831f02fffffffff
# DELEE
# 831f14fffffffff
# 8343acfffffffff 831f14fffffffff
# DEMHG
# 831faefffffffff
# 8343acfffffffff 831faefffffffff
# not a maritime hex id
# DENHA
# 831f14fffffffff
# 8343acfffffffff 831f14fffffffff
# DENOR
# 831f33fffffffff
# 8343acfffffffff 831f33fffffffff
# DEPFR
# 831f88fffffffff
# 8343acfffffffff 831f88fffffffff
# not a maritime hex id
# DERSK
# 831f00fffffffff
# 8343acfffffffff 831f00fffffffff
# DEWED
# 831f15fffffffff
# 8343acfffffffff 831f15fffffffff
# DEWOR
# 831faefffffffff
# 8343acfffffffff 831faefffffffff
# not a maritime hex id
# DEWVN
# 831f14fffffffff
# 8343acfffffffff 831f14fffffffff
# DJJIB
# 8352d4fffffffff
# 8343acfffffffff 8352d4fffffffff
# DJPOD
# 8352d4fffffffff
# 8343acfffffffff 8352d4fffffffff
# DKAAL
# 831f24fffffffff
# 8343acfffffffff 831f24fffffffff
# DKAAR
# 831f22fffffffff
# 8343acfffffffff 831f22fffffffff
# DKASN
# 831f31fffffffff
# 8343acfffffffff 831f31fffffffff
# DKCPH
# 831f05fffffffff
# 8343acfffffffff 831f05fffffffff
# DKEBJ
# 831f35fffffffff
# 8343acfffffffff 831f35fffffffff
# DKFRC
# 831f22fffffffff
# 8343acfffffffff 831f22fffffffff
# DKHIR
# 831f24fffffffff
# 8343acfffffffff 831f24fffffffff
# DKHLS
# 831f23fffffffff
# 8343acfffffffff 831f23fffffffff
# DKHSB
# 831f26fffffffff
# 8343acfffffffff 831f26fffffffff
# DKKAL
# 831f04fffffffff
# 8343acfffffffff 831f04fffffffff
# DKKTD
# 831f04fffffffff
# 8343acfffffffff 831f04fffffffff
# DKNBG
# 831f04fffffffff
# 8343acfffffffff 831f04fffffffff
# DKODE
# 831f04fffffffff
# 8343acfffffffff 831f04fffffffff
# DKRUG
# 831f23fffffffff
# 8343acfffffffff 831f23fffffffff
# DKSKA
# 831f24fffffffff
# 8343acfffffffff 831f24fffffffff
# DKSVE
# 831f04fffffffff
# 8343acfffffffff 831f04fffffffff
# DMRSU
# 835e42fffffffff
# 8343acfffffffff 835e42fffffffff
# DOCAU
# 834cd5fffffffff
# 8343acfffffffff 834cd5fffffffff
# DOHAI
# 834cd4fffffffff
# 8343acfffffffff 834cd4fffffffff
# DOMAN
# 834c88fffffffff
# 8343acfffffffff 834c88fffffffff
# DOPOP
# 834c89fffffffff
# 8343acfffffffff 834c89fffffffff
# DOSDQ
# 834cd4fffffffff
# 8343acfffffffff 834cd4fffffffff
# DOSPM
# 834cd5fffffffff
# 8343acfffffffff 834cd5fffffffff
# DZAAE
# 836a6bfffffffff
# 8343acfffffffff 836a6bfffffffff
# not a maritime hex id
# DZALG
# 833829fffffffff
# 8343acfffffffff 833829fffffffff
# DZBJA
# 833875fffffffff
# 8343acfffffffff 833875fffffffff
# DZGHA
# 83380bfffffffff
# 8343acfffffffff 83380bfffffffff
# not a maritime hex id
# DZMOS
# 83382efffffffff
# 8343acfffffffff 83382efffffffff
# DZORN
# 833823fffffffff
# 8343acfffffffff 833823fffffffff
# DZSKI
# 833862fffffffff
# 8343acfffffffff 833862fffffffff
# ECBHA
# 838f2efffffffff
# 8343acfffffffff 838f2efffffffff
# ECCHA
# 838f2afffffffff
# 8343acfffffffff 838f2afffffffff
# ECESM
# 8366d2fffffffff
# 8343acfffffffff 8366d2fffffffff
# ECGYE
# 838f2bfffffffff
# 8343acfffffffff 838f2bfffffffff
# ECLLD
# 838f2afffffffff
# 8343acfffffffff 838f2afffffffff
# ECMEC
# 838f2efffffffff
# 8343acfffffffff 838f2efffffffff
# ECMTV
# 838f2afffffffff
# 8343acfffffffff 838f2afffffffff
# ECPBO
# 838f0dfffffffff
# 8343acfffffffff 838f0dfffffffff
# EEHLD
# 83089efffffffff
# 8343acfffffffff 83089efffffffff
# EEMUG
# 83089bfffffffff
# 8343acfffffffff 83089bfffffffff
# EETLL
# 83089bfffffffff
# 8343acfffffffff 83089bfffffffff
# EGAIS
# 833e63fffffffff
# 8343acfffffffff 833e63fffffffff
# EGALY
# 833f59fffffffff
# 8343acfffffffff 833f59fffffffff
# EGDAM
# 833e64fffffffff
# 8343acfffffffff 833e64fffffffff
# EGEDK
# 833e66fffffffff
# 8343acfffffffff 833e66fffffffff
# EGPSD
# 833e65fffffffff
# 8343acfffffffff 833e65fffffffff
# EGSOK
# 833e63fffffffff
# 8343acfffffffff 833e63fffffffff
# EGSUZ
# 833e63fffffffff
# 8343acfffffffff 833e63fffffffff
# ERASA
# 8352f2fffffffff
# 8343acfffffffff 8352f2fffffffff
# ERMSW
# 8352a1fffffffff
# 8343acfffffffff 8352a1fffffffff
# ESACE
# 833469fffffffff
# 8343acfffffffff 833469fffffffff
# ESAGP
# 833919fffffffff
# 8343acfffffffff 833919fffffffff
# ESALC
# 833956fffffffff
# 8343acfffffffff 833956fffffffff
# ESALG
# 83391afffffffff
# 8343acfffffffff 83391afffffffff
# ESAVS
# 83185bfffffffff
# 8343acfffffffff 83185bfffffffff
# ESBCN
# 833944fffffffff
# 8343acfffffffff 833944fffffffff
# ESBIO
# 83184bfffffffff
# 8343acfffffffff 83184bfffffffff
# ESBRM
# 83184bfffffffff
# 8343acfffffffff 83184bfffffffff
# ESCAD
# 83391efffffffff
# 8343acfffffffff 83391efffffffff
# ESCAR
# 833825fffffffff
# 8343acfffffffff 833825fffffffff
# ESCAS
# 833954fffffffff
# 8343acfffffffff 833954fffffffff
# ESCEU
# 83391afffffffff
# 8343acfffffffff 83391afffffffff
# ESEBO
# ESFER
# 83390bfffffffff
# 8343acfffffffff 83390bfffffffff
# not a maritime hex id
# ESFUE
# 833469fffffffff
# 8343acfffffffff 833469fffffffff
# ESGIJ
# 83185bfffffffff
# 8343acfffffffff 83185bfffffffff
# ESHUV
# 833911fffffffff
# 8343acfffffffff 833911fffffffff
# ESIBZ
# 833951fffffffff
# 8343acfffffffff 833951fffffffff
# ESLCG
# 833925fffffffff
# 8343acfffffffff 833925fffffffff
# ESLEI
# 833824fffffffff
# 8343acfffffffff 833824fffffffff
# ESLPA
# 83346bfffffffff
# 8343acfffffffff 83346bfffffffff
# ESMAD
# 83390cfffffffff
# 8343acfffffffff 83390cfffffffff
# not a maritime hex id
# ESMAH
# 833943fffffffff
# 8343acfffffffff 833943fffffffff
# ESMLN
# 833835fffffffff
# 8343acfffffffff 833835fffffffff
# ESMOT
# 833919fffffffff
# 8343acfffffffff 833919fffffffff
# ESMPG
# 833920fffffffff
# 8343acfffffffff 833920fffffffff
# ESPAL
# 833945fffffffff
# 8343acfffffffff 833945fffffffff
# ESPAS
# 83184bfffffffff
# 8343acfffffffff 83184bfffffffff
# ESPMI
# 833942fffffffff
# 8343acfffffffff 833942fffffffff
# ESSCT
# 83344cfffffffff
# 8343acfffffffff 83344cfffffffff
# ESSDR
# 83392dfffffffff
# 8343acfffffffff 83392dfffffffff
# ESSNR
# 83184bfffffffff
# 8343acfffffffff 83184bfffffffff
# ESSPC
# 833441fffffffff
# 8343acfffffffff 833441fffffffff
# ESSVQ
# 83391cfffffffff
# 8343acfffffffff 83391cfffffffff
# not a maritime hex id
# ESTAR
# 833946fffffffff
# 8343acfffffffff 833946fffffffff
# ESTBZ
# 833974fffffffff
# 8343acfffffffff 833974fffffffff
# not a maritime hex id
# ESTCI
# 83344cfffffffff
# 8343acfffffffff 83344cfffffffff
# ESTOT
# 833973fffffffff
# 8343acfffffffff 833973fffffffff
# ESVGO
# 833920fffffffff
# 8343acfffffffff 833920fffffffff
# ESVLC
# 833954fffffffff
# 8343acfffffffff 833954fffffffff
# ESZAZ
# 833970fffffffff
# 8343acfffffffff 833970fffffffff
# not a maritime hex id
# FIHEL
# 831126fffffffff
# 8343acfffffffff 831126fffffffff
# FIHKO
# 830898fffffffff
# 8343acfffffffff 830898fffffffff
# FIHMN
# 831122fffffffff
# 8343acfffffffff 831122fffffffff
# FIKEM
# 8308c2fffffffff
# 8343acfffffffff 8308c2fffffffff
# FIKOK
# 8308d4fffffffff
# 8343acfffffffff 8308d4fffffffff
# FIKTK
# 831122fffffffff
# 8343acfffffffff 831122fffffffff
# FIMTL
# 830888fffffffff
# 8343acfffffffff 830888fffffffff
# FIOLU
# 8308d1fffffffff
# 8343acfffffffff 8308d1fffffffff
# FIOUL
# 8308d1fffffffff
# 8343acfffffffff 8308d1fffffffff
# FIPOR
# 830888fffffffff
# 8343acfffffffff 830888fffffffff
# FIRAU
# 83088efffffffff
# 8343acfffffffff 83088efffffffff
# FITKU
# 83089dfffffffff
# 8343acfffffffff 83089dfffffffff
# FITOR
# 8308c2fffffffff
# 8343acfffffffff 8308c2fffffffff
# FJLTK
# 839b6bfffffffff
# 8343acfffffffff 839b6bfffffffff
# FJSUV
# 839b41fffffffff
# 8343acfffffffff 839b41fffffffff
# FKPSY
# 83de70fffffffff
# 8343acfffffffff 83de70fffffffff
# FMPNI
# 837709fffffffff
# 8343acfffffffff 837709fffffffff
# FOTHO
# 831926fffffffff
# 8343acfffffffff 831926fffffffff
# FRBAS
# 83186bfffffffff
# 8343acfffffffff 83186bfffffffff
# FRBAY
# 831849fffffffff
# 8343acfffffffff 831849fffffffff
# FRBES
# 831871fffffffff
# 8343acfffffffff 831871fffffffff
# FRBOD
# 83184dfffffffff
# 8343acfffffffff 83184dfffffffff
# FRBOL
# 831948fffffffff
# 8343acfffffffff 831948fffffffff
# FRCQF
# 831948fffffffff
# 8343acfffffffff 831948fffffffff
# FRDKK
# 831948fffffffff
# 8343acfffffffff 831948fffffffff
# FRDPE
# 83194bfffffffff
# 8343acfffffffff 83194bfffffffff
# FRFOS
# 833968fffffffff
# 8343acfffffffff 833968fffffffff
# FRHGT
# 831fb3fffffffff
# 8343acfffffffff 831fb3fffffffff
# not a maritime hex id
# FRHON
# 831f91fffffffff
# 8343acfffffffff 831f91fffffffff
# not a maritime hex id
# FRJAV
# 831f91fffffffff
# 8343acfffffffff 831f91fffffffff
# not a maritime hex id
# FRLCT
# 833968fffffffff
# 8343acfffffffff 833968fffffffff
# FRLEH
# 831865fffffffff
# 8343acfffffffff 831865fffffffff
# FRLPC
# 831845fffffffff
# 8343acfffffffff 831845fffffffff
# FRLPE
# 83186afffffffff
# 8343acfffffffff 83186afffffffff
# FRLRH
# 83186afffffffff
# 8343acfffffffff 83186afffffffff
# FRLRT
# 831844fffffffff
# 8343acfffffffff 831844fffffffff
# FRLTR
# 83194bfffffffff
# 8343acfffffffff 83194bfffffffff
# FRLVE
# 83184cfffffffff
# 8343acfffffffff 83184cfffffffff
# FRMDH
# 831f85fffffffff
# 8343acfffffffff 831f85fffffffff
# not a maritime hex id
# FRMRS
# 833968fffffffff
# 8343acfffffffff 833968fffffffff
# FRMT7
# 833964fffffffff
# 8343acfffffffff 833964fffffffff
# not a maritime hex id
# FRMTX
# 831845fffffffff
# 8343acfffffffff 831845fffffffff
# FRNTE
# 831845fffffffff
# 8343acfffffffff 831845fffffffff
# FROR6
# 831fa6fffffffff
# 8343acfffffffff 831fa6fffffffff
# not a maritime hex id
# FRPAR
# 831fb4fffffffff
# 8343acfffffffff 831fb4fffffffff
# not a maritime hex id
# FRPIR
# 831845fffffffff
# 8343acfffffffff 831845fffffffff
# FRPOV
# 833945fffffffff
# 8343acfffffffff 833945fffffffff
# FRSET
# 83396efffffffff
# 8343acfffffffff 83396efffffffff
# FRSNR
# 831845fffffffff
# 8343acfffffffff 831845fffffffff
# FRTLN
# 833968fffffffff
# 8343acfffffffff 833968fffffffff
# FRURO
# 831865fffffffff
# 8343acfffffffff 831865fffffffff
# FRUSJ
# 83396dfffffffff
# 8343acfffffffff 83396dfffffffff
# not a maritime hex id
# GACLZ
# 83821bfffffffff
# 8343acfffffffff 83821bfffffffff
# GALBV
# 8382f0fffffffff
# 8343acfffffffff 8382f0fffffffff
# GAOWE
# 8382f4fffffffff
# 8343acfffffffff 8382f4fffffffff
# GAPOG
# 83821bfffffffff
# 8343acfffffffff 83821bfffffffff
# GBABD
# 831976fffffffff
# 8343acfffffffff 831976fffffffff
# GBAVO
# 831958fffffffff
# 8343acfffffffff 831958fffffffff
# GBBAD
# 831958fffffffff
# 8343acfffffffff 831958fffffffff
# GBBDT
# 831948fffffffff
# 8343acfffffffff 831948fffffffff
# GBBEL
# 831956fffffffff
# 8343acfffffffff 831956fffffffff
# GBBOC
# 83194efffffffff
# 8343acfffffffff 83194efffffffff
# GBBOE
# 831951fffffffff
# 8343acfffffffff 831951fffffffff
# GBBOS
# 831943fffffffff
# 8343acfffffffff 831943fffffffff
# GBBRK
# 831951fffffffff
# 8343acfffffffff 831951fffffffff
# GBBRS
# 831958fffffffff
# 8343acfffffffff 831958fffffffff
# GBBRT
# 831940fffffffff
# 8343acfffffffff 831940fffffffff
# GBBRW
# 83195bfffffffff
# 8343acfffffffff 83195bfffffffff
# GBCDF
# 831958fffffffff
# 8343acfffffffff 831958fffffffff
# GBCFG
# 831956fffffffff
# 8343acfffffffff 831956fffffffff
# GBCHD
# 831972fffffffff
# 8343acfffffffff 831972fffffffff
# GBCYN
# 831956fffffffff
# 8343acfffffffff 831956fffffffff
# GBDUN
# 831972fffffffff
# 8343acfffffffff 831972fffffffff
# GBDVR
# 831948fffffffff
# 8343acfffffffff 831948fffffffff
# GBEDI
# 831972fffffffff
# 8343acfffffffff 831972fffffffff
# GBEIL
# GBELL
# 831951fffffffff
# 8343acfffffffff 831951fffffffff
# GBEON
# 83195bfffffffff
# 8343acfffffffff 83195bfffffffff
# GBFAL
# 831870fffffffff
# 8343acfffffffff 831870fffffffff
# GBFAW
# 831959fffffffff
# 8343acfffffffff 831959fffffffff
# GBFRB
# 831929fffffffff
# 8343acfffffffff 831929fffffffff
# GBFXT
# 83194efffffffff
# 8343acfffffffff 83194efffffffff
# GBGCI
# 831862fffffffff
# 8343acfffffffff 831862fffffffff
# GBGLW
# 831909fffffffff
# 8343acfffffffff 831909fffffffff
# GBGOO
# 831942fffffffff
# 8343acfffffffff 831942fffffffff
# GBGRG
# 831972fffffffff
# 8343acfffffffff 831972fffffffff
# GBGRK
# 831909fffffffff
# 8343acfffffffff 831909fffffffff
# GBGSY
# 831940fffffffff
# 8343acfffffffff 831940fffffffff
# GBGTY
# 831941fffffffff
# 8343acfffffffff 831941fffffffff
# GBGVS
# 83194efffffffff
# 8343acfffffffff 83194efffffffff
# GBHRW
# 83194efffffffff
# 8343acfffffffff 83194efffffffff
# GBHUL
# 831940fffffffff
# 8343acfffffffff 831940fffffffff
# GBIMM
# 831940fffffffff
# 8343acfffffffff 831940fffffffff
# GBINK
# 831972fffffffff
# 8343acfffffffff 831972fffffffff
# GBINV
# 83190dfffffffff
# 8343acfffffffff 83190dfffffffff
# GBIPS
# 83194efffffffff
# 8343acfffffffff 83194efffffffff
# GBIRL
# 831951fffffffff
# 8343acfffffffff 831951fffffffff
# GBKLN
# 831943fffffffff
# 8343acfffffffff 831943fffffffff
# GBLAN
# 831955fffffffff
# 8343acfffffffff 831955fffffffff
# GBLGP
# 83194efffffffff
# 8343acfffffffff 83194efffffffff
# GBLIV
# 831951fffffffff
# 8343acfffffffff 831951fffffffff
# GBLON
# 83194afffffffff
# 8343acfffffffff 83194afffffffff
# GBMAL
# 83194efffffffff
# 8343acfffffffff 83194efffffffff
# GBMCD
# 831929fffffffff
# 8343acfffffffff 831929fffffffff
# GBMID
# 831946fffffffff
# 8343acfffffffff 831946fffffffff
# GBMNS
# 831928fffffffff
# 8343acfffffffff 831928fffffffff
# GBMON
# 831976fffffffff
# 8343acfffffffff 831976fffffffff
# GBMRY
# 831954fffffffff
# 8343acfffffffff 831954fffffffff
# GBNCL
# 831973fffffffff
# 8343acfffffffff 831973fffffffff
# GBNFT
# 83194efffffffff
# 8343acfffffffff 83194efffffffff
# GBNHV
# 83194afffffffff
# 8343acfffffffff 83194afffffffff
# GBNLN
# 831942fffffffff
# 8343acfffffffff 831942fffffffff
# GBNPT
# 831958fffffffff
# 8343acfffffffff 831958fffffffff
# GBPDD
# GBPFT
# 83194efffffffff
# 8343acfffffffff 83194efffffffff
# GBPLY
# 831874fffffffff
# 8343acfffffffff 831874fffffffff
# GBPME
# 831959fffffffff
# 8343acfffffffff 831959fffffffff
# GBPOO
# 831959fffffffff
# 8343acfffffffff 831959fffffffff
# GBPRE
# 831951fffffffff
# 8343acfffffffff 831951fffffffff
# GBPRU
# 831958fffffffff
# 8343acfffffffff 831958fffffffff
# GBPST
# 83194efffffffff
# 8343acfffffffff 83194efffffffff
# GBQUB
# 83194efffffffff
# 8343acfffffffff 83194efffffffff
# GBRYE
# 83194afffffffff
# 8343acfffffffff 83194afffffffff
# GBSCA
# 831946fffffffff
# 8343acfffffffff 831946fffffffff
# GBSHS
# 83194efffffffff
# 8343acfffffffff 83194efffffffff
# GBSOU
# 831959fffffffff
# 8343acfffffffff 831959fffffffff
# GBSOW
# 83195cfffffffff
# 8343acfffffffff 83195cfffffffff
# not a maritime hex id
# GBSSH
# 831973fffffffff
# 8343acfffffffff 831973fffffffff
# GBSUN
# 831946fffffffff
# 8343acfffffffff 831946fffffffff
# GBSVT
# 83194afffffffff
# 8343acfffffffff 83194afffffffff
# GBSWA
# 83195afffffffff
# 8343acfffffffff 83195afffffffff
# GBTEE
# 831946fffffffff
# 8343acfffffffff 831946fffffffff
# GBTHP
# 83194afffffffff
# 8343acfffffffff 83194afffffffff
# GBTIL
# 83194efffffffff
# 8343acfffffffff 83194efffffffff
# GBTYN
# 831973fffffffff
# 8343acfffffffff 831973fffffffff
# GBWDN
# 831951fffffffff
# 8343acfffffffff 831951fffffffff
# GBWOR
# 831950fffffffff
# 8343acfffffffff 831950fffffffff
# GBYVZ
# 831958fffffffff
# 8343acfffffffff 831958fffffffff
# GDSTG
# 835e66fffffffff
# 8343acfffffffff 835e66fffffffff
# GEBUS
# 832c21fffffffff
# 8343acfffffffff 832c21fffffffff
# GEPTI
# 832c21fffffffff
# 8343acfffffffff 832c21fffffffff
# GETBS
# 832c2afffffffff
# 8343acfffffffff 832c2afffffffff
# not a maritime hex id
# GFCAY
# 835f12fffffffff
# 8343acfffffffff 835f12fffffffff
# GFDDC
# 835f12fffffffff
# 8343acfffffffff 835f12fffffffff
# GHTEM
# 837529fffffffff
# 8343acfffffffff 837529fffffffff
# GHTKD
# 837509fffffffff
# 8343acfffffffff 837509fffffffff
# GIGIB
# 83391afffffffff
# 8343acfffffffff 83391afffffffff
# GMBJL
# 8354a9fffffffff
# 8343acfffffffff 8354a9fffffffff
# GNCKY
# 8354eafffffffff
# 8343acfffffffff 8354eafffffffff
# GPBBR
# 835e43fffffffff
# 8343acfffffffff 835e43fffffffff
# GPGUS
# 834d49fffffffff
# 8343acfffffffff 834d49fffffffff
# GPPTP
# 835e43fffffffff
# 8343acfffffffff 835e43fffffffff
# GPSBH
# 835e43fffffffff
# 8343acfffffffff 835e43fffffffff
# GQBSG
# 8382f2fffffffff
# 8343acfffffffff 8382f2fffffffff
# GQSSG
# 8382d0fffffffff
# 8343acfffffffff 8382d0fffffffff
# GRAST
# 833f2cfffffffff
# 8343acfffffffff 833f2cfffffffff
# GREEU
# 831edafffffffff
# 8343acfffffffff 831edafffffffff
# GRHER
# 833f73fffffffff
# 8343acfffffffff 833f73fffffffff
# GRKAP
# GRPIR
# 831edafffffffff
# 8343acfffffffff 831edafffffffff
# GRRHO
# 833f44fffffffff
# 8343acfffffffff 833f44fffffffff
# GRSKG
# 831edcfffffffff
# 8343acfffffffff 831edcfffffffff
# GRVOL
# 831edefffffffff
# 8343acfffffffff 831edefffffffff
# GTCHR
# 836d2bfffffffff
# 8343acfffffffff 836d2bfffffffff
# GTGUA
# 836d29fffffffff
# 8343acfffffffff 836d29fffffffff
# not a maritime hex id
# GTPBR
# 834520fffffffff
# 8343acfffffffff 834520fffffffff
# GTPRQ
# 836d76fffffffff
# 8343acfffffffff 836d76fffffffff
# GTSTC
# 834520fffffffff
# 8343acfffffffff 834520fffffffff
# GUGUM
# 834f49fffffffff
# 8343acfffffffff 834f49fffffffff
# GWOXB
# 8354f5fffffffff
# 8343acfffffffff 8354f5fffffffff
# GYGEO
# 835f09fffffffff
# 8343acfffffffff 835f09fffffffff
# HKHKG
# 83411cfffffffff
# 8343acfffffffff 83411cfffffffff
# HNAMP
# 836d66fffffffff
# 8343acfffffffff 836d66fffffffff
# HNLCE
# 834531fffffffff
# 8343acfffffffff 834531fffffffff
# HNPCA
# 834531fffffffff
# 8343acfffffffff 834531fffffffff
# HNPCR
# 834522fffffffff
# 8343acfffffffff 834522fffffffff
# HNRTB
# 834531fffffffff
# 8343acfffffffff 834531fffffffff
# HNSLO
# 836d66fffffffff
# 8343acfffffffff 836d66fffffffff
# HNTEA
# 834522fffffffff
# 8343acfffffffff 834522fffffffff
# HNTGU
# HRDBV
# 831e8dfffffffff
# 8343acfffffffff 831e8dfffffffff
# HRLST
# HRPLE
# 831eabfffffffff
# 8343acfffffffff 831eabfffffffff
# HRRJK
# 831e12fffffffff
# 8343acfffffffff 831e12fffffffff
# HRSPU
# 831eabfffffffff
# 8343acfffffffff 831eabfffffffff
# HTCAP
# 834c88fffffffff
# 8343acfffffffff 834c88fffffffff
# HTPAP
# 836725fffffffff
# 8343acfffffffff 836725fffffffff
# HUBUD
# 831e03fffffffff
# 8343acfffffffff 831e03fffffffff
# not a maritime hex id
# IDAMA
# 83729dfffffffff
# 8343acfffffffff 83729dfffffffff
# IDBDJ
# 838d92fffffffff
# 8343acfffffffff 838d92fffffffff
# IDBIT
# 8368c8fffffffff
# 8343acfffffffff 8368c8fffffffff
# IDBLW
# 836508fffffffff
# 8343acfffffffff 836508fffffffff
# IDBNT
# 838cd2fffffffff
# 8343acfffffffff 838cd2fffffffff
# not a maritime hex id
# IDBPN
# 83688afffffffff
# 8343acfffffffff 83688afffffffff
# IDBTM
# 836526fffffffff
# 8343acfffffffff 836526fffffffff
# IDBUN
# 836521fffffffff
# 8343acfffffffff 836521fffffffff
# IDBUR
# 83688afffffffff
# 8343acfffffffff 83688afffffffff
# IDCIG
# 838c13fffffffff
# 8343acfffffffff 838c13fffffffff
# IDDJB
# 838c89fffffffff
# 8343acfffffffff 838c89fffffffff
# not a maritime hex id
# IDDJJ
# 8372f3fffffffff
# 8343acfffffffff 8372f3fffffffff
# IDJKT
# 838c10fffffffff
# 8343acfffffffff 838c10fffffffff
# IDKAB
# 836526fffffffff
# 8343acfffffffff 836526fffffffff
# IDLBM
# 836526fffffffff
# 8343acfffffffff 836526fffffffff
# IDMAK
# 839500fffffffff
# 8343acfffffffff 839500fffffffff
# IDMES
# 83650dfffffffff
# 8343acfffffffff 83650dfffffffff
# not a maritime hex id
# IDMRK
# 838c13fffffffff
# 8343acfffffffff 838c13fffffffff
# IDPDG
# 838cd1fffffffff
# 8343acfffffffff 838cd1fffffffff
# IDPJG
# 838cadfffffffff
# 8343acfffffffff 838cadfffffffff
# IDPKU
# 83652cfffffffff
# 8343acfffffffff 83652cfffffffff
# not a maritime hex id
# IDPLM
# 838cabfffffffff
# 8343acfffffffff 838cabfffffffff
# not a maritime hex id
# IDPNJ
# 838cadfffffffff
# 8343acfffffffff 838cadfffffffff
# IDPNK
# 838c95fffffffff
# 8343acfffffffff 838c95fffffffff
# IDPWG
# 836521fffffffff
# 8343acfffffffff 836521fffffffff
# IDSEQ
# 836521fffffffff
# 8343acfffffffff 836521fffffffff
# IDSRG
# 838d8cfffffffff
# 8343acfffffffff 838d8cfffffffff
# IDSRI
# 83688afffffffff
# 8343acfffffffff 83688afffffffff
# IDSUB
# 838d80fffffffff
# 8343acfffffffff 838d80fffffffff
# IDTAB
# 838d92fffffffff
# 8343acfffffffff 838d92fffffffff
# IDTBG
# 838cadfffffffff
# 8343acfffffffff 838cadfffffffff
# IDTPP
# 838c10fffffffff
# 8343acfffffffff 838c10fffffffff
# IDTTI
# 83650cfffffffff
# 8343acfffffffff 83650cfffffffff
# IDUPG
# 839500fffffffff
# 8343acfffffffff 839500fffffffff
# IEDRO
# 83182cfffffffff
# 8343acfffffffff 83182cfffffffff
# IEDUB
# 83182cfffffffff
# 8343acfffffffff 83182cfffffffff
# IEFOV
# 831805fffffffff
# 8343acfffffffff 831805fffffffff
# IEGWY
# 83182efffffffff
# 8343acfffffffff 83182efffffffff
# IEKLN
# 83182afffffffff
# 8343acfffffffff 83182afffffffff
# IEORK
# 83182afffffffff
# 8343acfffffffff 83182afffffffff
# IEWAT
# 831828fffffffff
# 8343acfffffffff 831828fffffffff
# ILASH
# 832db6fffffffff
# 8343acfffffffff 832db6fffffffff
# ILHAD
# 832db0fffffffff
# 8343acfffffffff 832db0fffffffff
# ILHFA
# 832db0fffffffff
# 8343acfffffffff 832db0fffffffff
# ILNAT
# 832db0fffffffff
# 8343acfffffffff 832db0fffffffff
# ILRMG
# 832db0fffffffff
# 8343acfffffffff 832db0fffffffff
# ILTLV
# 832db0fffffffff
# 8343acfffffffff 832db0fffffffff
# INAGR
# 833d85fffffffff
# 8343acfffffffff 833d85fffffffff
# not a maritime hex id
# INKAK
# 833c92fffffffff
# 8343acfffffffff 833c92fffffffff
# INAMD
# 8342cefffffffff
# 8343acfffffffff 8342cefffffffff
# INBLR
# 836014fffffffff
# 8343acfffffffff 836014fffffffff
# not a maritime hex id
# INBOM
# 83608bfffffffff
# 8343acfffffffff 83608bfffffffff
# INCCU
# 833cf2fffffffff
# 8343acfffffffff 833cf2fffffffff
# INCDL
# 8361abfffffffff
# 8343acfffffffff 8361abfffffffff
# INCJB
# 836033fffffffff
# 8343acfffffffff 836033fffffffff
# not a maritime hex id
# INCOK
# 836004fffffffff
# 8343acfffffffff 836004fffffffff
# INDAM
# 8342dbfffffffff
# 8343acfffffffff 8342dbfffffffff
# INDRI
# 833da1fffffffff
# 8343acfffffffff 833da1fffffffff
# not a maritime hex id
# INGOI
# 8360a9fffffffff
# 8343acfffffffff 8360a9fffffffff
# INHAL
# 833c8dfffffffff
# 8343acfffffffff 833c8dfffffffff
# INHYD
# 8360a4fffffffff
# 8343acfffffffff 8360a4fffffffff
# not a maritime hex id
# INICD
# 833da1fffffffff
# 8343acfffffffff 833da1fffffffff
# not a maritime hex id
# INIXE
# 836011fffffffff
# 8343acfffffffff 836011fffffffff
# INIXY
# 8342c0fffffffff
# 8343acfffffffff 8342c0fffffffff
# INJAI
# 833da2fffffffff
# 8343acfffffffff 833da2fffffffff
# not a maritime hex id
# INJDH
# 83425afffffffff
# 8343acfffffffff 83425afffffffff
# not a maritime hex id
# INKNU
# 833d8cfffffffff
# 8343acfffffffff 833d8cfffffffff
# not a maritime hex id
# INKRI
# 83619dfffffffff
# 8343acfffffffff 83619dfffffffff
# INLUH
# 834249fffffffff
# 8343acfffffffff 834249fffffffff
# not a maritime hex id
# INMAA
# 83618cfffffffff
# 8343acfffffffff 83618cfffffffff
# INMOR
# 833dacfffffffff
# 8343acfffffffff 833dacfffffffff
# not a maritime hex id
# INMRM
# 8360a9fffffffff
# 8343acfffffffff 8360a9fffffffff
# INMUN
# 8342c4fffffffff
# 8343acfffffffff 8342c4fffffffff
# INNAG
# 836096fffffffff
# 8343acfffffffff 836096fffffffff
# not a maritime hex id
# INNSA
# 83608bfffffffff
# 8343acfffffffff 83608bfffffffff
# INPAP
# 833d12fffffffff
# 8343acfffffffff 833d12fffffffff
# not a maritime hex id
# INPAV
# 8342dcfffffffff
# 8343acfffffffff 8342dcfffffffff
# INPIR
# 833d96fffffffff
# 8343acfffffffff 833d96fffffffff
# not a maritime hex id
# INPNQ
# 836088fffffffff
# 8343acfffffffff 836088fffffffff
# not a maritime hex id
# INSTV
# 8342d9fffffffff
# 8343acfffffffff 8342d9fffffffff
# INTUT
# 83611bfffffffff
# 8343acfffffffff 83611bfffffffff
# INVTZ
# 833c93fffffffff
# 8343acfffffffff 833c93fffffffff
# INVVA
# 8342d1fffffffff
# 8343acfffffffff 8342d1fffffffff
# IQUQR
# 832c91fffffffff
# 8343acfffffffff 832c91fffffffff
# IRBKM
# 832c98fffffffff
# 8343acfffffffff 832c98fffffffff
# IRBND
# 83431efffffffff
# 8343acfffffffff 83431efffffffff
# IRBUZ
# 834334fffffffff
# 8343acfffffffff 834334fffffffff
# IRKHO
# 832c9cfffffffff
# 8343acfffffffff 832c9cfffffffff
# not a maritime hex id
# IRZBR
# 834233fffffffff
# 8343acfffffffff 834233fffffffff
# ISESK
# 83ab25fffffffff
# 8343acfffffffff 83ab25fffffffff
# ISGRT
# 83075dfffffffff
# 8343acfffffffff 83075dfffffffff
# ISREY
# 83075dfffffffff
# 8343acfffffffff 83075dfffffffff
# ITAOI
# 831ea3fffffffff
# 8343acfffffffff 831ea3fffffffff
# ITAUG
# 833f35fffffffff
# 8343acfffffffff 833f35fffffffff
# ITBRI
# 831e88fffffffff
# 8343acfffffffff 831e88fffffffff
# ITCAG
# 831e92fffffffff
# 8343acfffffffff 831e92fffffffff
# ITCRV
# 833f24fffffffff
# 8343acfffffffff 833f24fffffffff
# ITCTA
# 833f35fffffffff
# 8343acfffffffff 833f35fffffffff
# ITCVV
# 831e86fffffffff
# 8343acfffffffff 831e86fffffffff
# ITFAE
# 831ea0fffffffff
# 8343acfffffffff 831ea0fffffffff
# ITGAE
# 831e83fffffffff
# 8343acfffffffff 831e83fffffffff
# ITGIT
# 833f26fffffffff
# 8343acfffffffff 833f26fffffffff
# ITGOA
# 831f9bfffffffff
# 8343acfffffffff 831f9bfffffffff
# ITLIV
# 831eb5fffffffff
# 8343acfffffffff 831eb5fffffffff
# ITMIL
# 831f99fffffffff
# 8343acfffffffff 831f99fffffffff
# not a maritime hex id
# ITMNF
# 831e12fffffffff
# 8343acfffffffff 831e12fffffffff
# ITMOD
# 831ea6fffffffff
# 8343acfffffffff 831ea6fffffffff
# not a maritime hex id
# ITNAP
# 831e83fffffffff
# 8343acfffffffff 831e83fffffffff
# ITPDA
# 831ea4fffffffff
# 8343acfffffffff 831ea4fffffffff
# not a maritime hex id
# ITPES
# 831ea3fffffffff
# 8343acfffffffff 831ea3fffffffff
# ITPGA
# 831ea0fffffffff
# 8343acfffffffff 831ea0fffffffff
# ITPMO
# 831e9afffffffff
# 8343acfffffffff 831e9afffffffff
# ITPRJ
# 831e9dfffffffff
# 8343acfffffffff 831e9dfffffffff
# ITPSR
# 831e81fffffffff
# 8343acfffffffff 831e81fffffffff
# ITPVE
# 833865fffffffff
# 8343acfffffffff 833865fffffffff
# ITRAN
# 831ea0fffffffff
# 8343acfffffffff 831ea0fffffffff
# ITSAL
# 831e9dfffffffff
# 8343acfffffffff 831e9dfffffffff
# ITSPE
# 831eb5fffffffff
# ...
# 8343acfffffffff 836d74fffffffff
# SYDAM
# 832db1fffffffff
# 8343acfffffffff 832db1fffffffff
# SYLTK
# 832da3fffffffff
# 8343acfffffffff 832da3fffffffff
# SYTTS
# 832da3fffffffff
# 8343acfffffffff 832da3fffffffff
# TCPLS
# 834c81fffffffff
# 8343acfffffffff 834c81fffffffff
# TGLFW
# 835890fffffffff
# 8343acfffffffff 835890fffffffff
# THBGP
# 8364a4fffffffff
# 8343acfffffffff 8364a4fffffffff
# not a maritime hex id
# THBKK
# 8364a4fffffffff
# 8343acfffffffff 8364a4fffffffff
# not a maritime hex id
# THBMT
# 8364a4fffffffff
# 8343acfffffffff 8364a4fffffffff
# not a maritime hex id
# THKSI
# 83658bfffffffff
# 8343acfffffffff 83658bfffffffff
# THKTY
# 8364a4fffffffff
# 8343acfffffffff 8364a4fffffffff
# not a maritime hex id
# THLCH
# 83658bfffffffff
# 8343acfffffffff 83658bfffffffff
# THLKR
# THMAT
# 8364a4fffffffff
# 8343acfffffffff 8364a4fffffffff
# not a maritime hex id
# THPAT
# 8364a4fffffffff
# 8343acfffffffff 8364a4fffffffff
# not a maritime hex id
# THPKN
# 83659afffffffff
# 8343acfffffffff 83659afffffffff
# not a maritime hex id
# THSBP
# 8364a4fffffffff
# 8343acfffffffff 8364a4fffffffff
# not a maritime hex id
# THSGZ
# 836518fffffffff
# 8343acfffffffff 836518fffffffff
# THSPR
# 8364a4fffffffff
# 8343acfffffffff 8364a4fffffffff
# not a maritime hex id
# THSRI
# 83658bfffffffff
# 8343acfffffffff 83658bfffffffff
# THTPT
# TNGAE
# 83384efffffffff
# 8343acfffffffff 83384efffffffff
# TNJAR
# 8339a2fffffffff
# 8343acfffffffff 8339a2fffffffff
# TNLGN
# 83386efffffffff
# 8343acfffffffff 83386efffffffff
# TNRDS
# 83386efffffffff
# 8343acfffffffff 83386efffffffff
# TNSFA
# 83384cfffffffff
# 8343acfffffffff 83384cfffffffff
# TNSUS
# 83386afffffffff
# 8343acfffffffff 83386afffffffff
# TNTUN
# 83386efffffffff
# 8343acfffffffff 83386efffffffff
# TOTBU
# 839b0cfffffffff
# 8343acfffffffff 839b0cfffffffff
# TRALI
# 833f64fffffffff
# 8343acfffffffff 833f64fffffffff
# TRAMB
# 832c20fffffffff
# 8343acfffffffff 832c20fffffffff
# TRAVC
# 831ec9fffffffff
# 8343acfffffffff 831ec9fffffffff
# TRAYT
# 833f6efffffffff
# 8343acfffffffff 833f6efffffffff
# TRBAY
# 831ec9fffffffff
# 8343acfffffffff 831ec9fffffffff
# TRBDM
# 831ecbfffffffff
# 8343acfffffffff 831ecbfffffffff
# TREYP
# 831ec9fffffffff
# 8343acfffffffff 831ec9fffffffff
# TRGEB
# 831ec9fffffffff
# 8343acfffffffff 831ec9fffffffff
# TRGEM
# 831ec9fffffffff
# 8343acfffffffff 831ec9fffffffff
# TRHAY
# 831ec9fffffffff
# 8343acfffffffff 831ec9fffffffff
# TRHER
# 831ec9fffffffff
# 8343acfffffffff 831ec9fffffffff
# TRISK
# 832da1fffffffff
# 8343acfffffffff 832da1fffffffff
# TRIST
# 831ec9fffffffff
# 8343acfffffffff 831ec9fffffffff
# TRIZM
# 833f66fffffffff
# 8343acfffffffff 833f66fffffffff
# TRIZT
# 832d35fffffffff
# 8343acfffffffff 832d35fffffffff
# TRKMX
# 831ec9fffffffff
# 8343acfffffffff 831ec9fffffffff
# TRMAD
# 831ec9fffffffff
# 8343acfffffffff 831ec9fffffffff
# TRMAR
# 831ec8fffffffff
# 8343acfffffffff 831ec8fffffffff
# TRMER
# 832da5fffffffff
# 8343acfffffffff 832da5fffffffff
# TRNEM
# 833f66fffffffff
# 8343acfffffffff 833f66fffffffff
# TRSSX
# 832d03fffffffff
# 8343acfffffffff 832d03fffffffff
# TRTEK
# 831ec8fffffffff
# 8343acfffffffff 831ec8fffffffff
# TRTZX
# 832c24fffffffff
# 8343acfffffffff 832c24fffffffff
# TRYAR
# 831ec9fffffffff
# 8343acfffffffff 831ec9fffffffff
# TTPOS
# 835f59fffffffff
# 8343acfffffffff 835f59fffffffff
# TTPTP
# 835f58fffffffff
# 8343acfffffffff 835f58fffffffff
# TTPTS
# 835f58fffffffff
# 8343acfffffffff 835f58fffffffff
# TTSFE
# 835f58fffffffff
# 8343acfffffffff 835f58fffffffff
# TWKEL
# 834ba1fffffffff
# 8343acfffffffff 834ba1fffffffff
# TWKHH
# 834bb1fffffffff
# 8343acfffffffff 834bb1fffffffff
# TWMLI
# 834bb1fffffffff
# 8343acfffffffff 834bb1fffffffff
# TWSUO
# 834ba1fffffffff
# 8343acfffffffff 834ba1fffffffff
# TWTPE
# TWTXG
# 834ba2fffffffff
# 8343acfffffffff 834ba2fffffffff
# TWTYN
# 834ba0fffffffff
# 8343acfffffffff 834ba0fffffffff
# TZDAR
# 837b4cfffffffff
# 8343acfffffffff 837b4cfffffffff
# TZTGT
# 837b48fffffffff
# 8343acfffffffff 837b48fffffffff
# TZZNZ
# 837b4cfffffffff
# 8343acfffffffff 837b4cfffffffff
# UAIEV
# 831e63fffffffff
# 8343acfffffffff 831e63fffffffff
# not a maritime hex id
# UAILK
# 831e5dfffffffff
# 8343acfffffffff 831e5dfffffffff
# UAKHE
# 831e4afffffffff
# 8343acfffffffff 831e4afffffffff
# UAMPW
# 832d62fffffffff
# 8343acfffffffff 832d62fffffffff
# UAODS
# 831e5dfffffffff
# 8343acfffffffff 831e5dfffffffff
# UASVP
# 832d28fffffffff
# 8343acfffffffff 832d28fffffffff
# UGJIN
# 836acdfffffffff
# 8343acfffffffff 836acdfffffffff
# not a maritime hex id
# UGKLA
# 836accfffffffff
# 8343acfffffffff 836accfffffffff
# not a maritime hex id
# USADQ
# 830c5afffffffff
# 8343acfffffffff 830c5afffffffff
# USANC
# 830c73fffffffff
# 8343acfffffffff 830c73fffffffff
# USANP
# 832aa8fffffffff
# 8343acfffffffff 832aa8fffffffff
# USAR5
# 83265afffffffff
# 8343acfffffffff 83265afffffffff
# not a maritime hex id
# USATL
# 8344c1fffffffff
# 8343acfffffffff 8344c1fffffffff
# not a maritime hex id
# USBAL
# 832aa8fffffffff
# 8343acfffffffff 832aa8fffffffff
# USBCC
# 830c42fffffffff
# 8343acfffffffff 830c42fffffffff
# USBHM
# USBNA
# 83264dfffffffff
# 8343acfffffffff 83264dfffffffff
# not a maritime hex id
# USBOS
# 832a30fffffffff
# 8343acfffffffff 832a30fffffffff
# USBPT
# 83446efffffffff
# 8343acfffffffff 83446efffffffff
# USBRO
# 8348b2fffffffff
# 8343acfffffffff 8348b2fffffffff
# USBUF
# 832aa6fffffffff
# 8343acfffffffff 832aa6fffffffff
# not a maritime hex id
# USCBF
# USCHA
# 8344cdfffffffff
# 8343acfffffffff 8344cdfffffffff
# not a maritime hex id
# USCHI
# 832664fffffffff
# 8343acfffffffff 832664fffffffff
# not a maritime hex id
# USCHS
# 8344d0fffffffff
# 8343acfffffffff 8344d0fffffffff
# USCLE
# 832ab3fffffffff
# 8343acfffffffff 832ab3fffffffff
# not a maritime hex id
# USCLM
# 8328d1fffffffff
# 8343acfffffffff 8328d1fffffffff
# USCLT
# 8344d8fffffffff
# 8343acfffffffff 8344d8fffffffff
# not a maritime hex id
# USCMH
# 832a95fffffffff
# 8343acfffffffff 832a95fffffffff
# not a maritime hex id
# USCPF
# USCPV
# 8344abfffffffff
# 8343acfffffffff 8344abfffffffff
# USCRP
# 834895fffffffff
# 8343acfffffffff 834895fffffffff
# USCVG
# 832a93fffffffff
# 8343acfffffffff 832a93fffffffff
# not a maritime hex id
# USCZF
# 830cadfffffffff
# 8343acfffffffff 830cadfffffffff
# USDA8
# 832aa1fffffffff
# 8343acfffffffff 832aa1fffffffff
# not a maritime hex id
# USDAL
# 8326cbfffffffff
# 8343acfffffffff 8326cbfffffffff
# not a maritime hex id
# USDEC
# 832662fffffffff
# 8343acfffffffff 832662fffffffff
# not a maritime hex id
# USDEN
# 83268cfffffffff
# 8343acfffffffff 83268cfffffffff
# not a maritime hex id
# USDET
# 832ab2fffffffff
# 8343acfffffffff 832ab2fffffffff
# not a maritime hex id
# USDNN
# 8344ccfffffffff
# 8343acfffffffff 8344ccfffffffff
# not a maritime hex id
# USDSM
# 83260dfffffffff
# 8343acfffffffff 83260dfffffffff
# not a maritime hex id
# USDUT
# 8322d0fffffffff
# 8343acfffffffff 8322d0fffffffff
# USELP
# 8348c6fffffffff
# 8343acfffffffff 8348c6fffffffff
# not a maritime hex id
# USENA
# 830c55fffffffff
# 8343acfffffffff 830c55fffffffff
# USEWR
# 832a10fffffffff
# 8343acfffffffff 832a10fffffffff
# USFEB
# 8344f0fffffffff
# 8343acfffffffff 8344f0fffffffff
# USFLL
# 8344a1fffffffff
# 8343acfffffffff 8344a1fffffffff
# USFPO
# 834892fffffffff
# 8343acfffffffff 834892fffffffff
# USFRP
# 831d24fffffffff
# 8343acfffffffff 831d24fffffffff
# USFWT
# 8326cbfffffffff
# 8343acfffffffff 8326cbfffffffff
# not a maritime hex id
# USGBO
# USGLS
# 83446cfffffffff
# 8343acfffffffff 83446cfffffffff
# USGPT
# 834455fffffffff
# 8343acfffffffff 834455fffffffff
# USGSP
# USHNL
# 83464bfffffffff
# 8343acfffffffff 83464bfffffffff
# USHOU
# 83446cfffffffff
# 8343acfffffffff 83446cfffffffff
# USHSV
# 832649fffffffff
# 8343acfffffffff 832649fffffffff
# not a maritime hex id
# USILM
# 832ad0fffffffff
# 8343acfffffffff 832ad0fffffffff
# USIND
# 832661fffffffff
# 8343acfffffffff 832661fffffffff
# not a maritime hex id
# USJ3C
# 83281efffffffff
# 8343acfffffffff 83281efffffffff
# not a maritime hex id
# USJAX
# 8344f0fffffffff
# 8343acfffffffff 8344f0fffffffff
# USJOT
# USKCK
# 832656fffffffff
# 8343acfffffffff 832656fffffffff
# not a maritime hex id
# USLAS
# 832986fffffffff
# 8343acfffffffff 832986fffffffff
# not a maritime hex id
# USLAT
# 8329a5fffffffff
# 8343acfffffffff 8329a5fffffffff
# USLAX
# 8329a1fffffffff
# 8343acfffffffff 8329a1fffffffff
# USLCH
# 834445fffffffff
# 8343acfffffffff 834445fffffffff
# not a maritime hex id
# USLGB
# 8329a5fffffffff
# 8343acfffffffff 8329a5fffffffff
# USLRD
# 834880fffffffff
# 8343acfffffffff 834880fffffffff
# not a maritime hex id
# USLUI
# 832668fffffffff
# 8343acfffffffff 832668fffffffff
# not a maritime hex id
# USMEM
# 832659fffffffff
# 8343acfffffffff 832659fffffffff
# not a maritime hex id
# USMES
# 832752fffffffff
# 8343acfffffffff 832752fffffffff
# not a maritime hex id
# USMIA
# 8344a1fffffffff
# 8343acfffffffff 8344a1fffffffff
# USMKC
# 832656fffffffff
# 8343acfffffffff 832656fffffffff
# not a maritime hex id
# USMKE
# 83275dfffffffff
# 8343acfffffffff 83275dfffffffff
# not a maritime hex id
# USMOB
# 834450fffffffff
# 8343acfffffffff 834450fffffffff
# USMRH
# 832ad5fffffffff
# 8343acfffffffff 832ad5fffffffff
# USMSP
# 83262cfffffffff
# 8343acfffffffff 83262cfffffffff
# not a maritime hex id
# USMSY
# 834446fffffffff
# 8343acfffffffff 834446fffffffff
# USNNS
# 832af6fffffffff
# 8343acfffffffff 832af6fffffffff
# USNTD
# 832912fffffffff
# 8343acfffffffff 832912fffffffff
# USNTS
# 8344d0fffffffff
# 8343acfffffffff 8344d0fffffffff
# USNYC
# 832a10fffffffff
# 8343acfffffffff 832a10fffffffff
# USOAK
# 832830fffffffff
# 8343acfffffffff 832830fffffffff
# USOCN
# 8329a4fffffffff
# 8343acfffffffff 8329a4fffffffff
# USOCW
# 832ad4fffffffff
# 8343acfffffffff 832ad4fffffffff
# USOLM
# 8328d5fffffffff
# 8343acfffffffff 8328d5fffffffff
# USOMA
# 83260efffffffff
# 8343acfffffffff 83260efffffffff
# not a maritime hex id
# USORF
# 832af6fffffffff
# 8343acfffffffff 832af6fffffffff
# USORL
# 8344a9fffffffff
# 8343acfffffffff 8344a9fffffffff
# USOYM
# 8329a4fffffffff
# 8343acfffffffff 8329a4fffffffff
# USPAB
# 8344aefffffffff
# 8343acfffffffff 8344aefffffffff
# USPCA
# 830ce3fffffffff
# 8343acfffffffff 830ce3fffffffff
# USPCV
# 8344abfffffffff
# 8343acfffffffff 8344abfffffffff
# USPDX
# 8328f0fffffffff
# 8343acfffffffff 8328f0fffffffff
# not a maritime hex id
# USPEB
# 832aadfffffffff
# 8343acfffffffff 832aadfffffffff
# USPEF
# 8344a1fffffffff
# 8343acfffffffff 8344a1fffffffff
# USPFN
# 8344e5fffffffff
# 8343acfffffffff 8344e5fffffffff
# USPGL
# 834450fffffffff
# 8343acfffffffff 834450fffffffff
# USPHF
# 832af6fffffffff
# 8343acfffffffff 832af6fffffffff
# USPHL
# 832a13fffffffff
# 8343acfffffffff 832a13fffffffff
# USPHX
# 8329b6fffffffff
# 8343acfffffffff 8329b6fffffffff
# not a maritime hex id
# USPIA
# 832662fffffffff
# 8343acfffffffff 832662fffffffff
# not a maritime hex id
# USPIT
# 832a84fffffffff
# 8343acfffffffff 832a84fffffffff
# not a maritime hex id
# USPME
# 83441efffffffff
# 8343acfffffffff 83441efffffffff
# USPNS
# 834456fffffffff
# 8343acfffffffff 834456fffffffff
# USPOA
# 83446efffffffff
# 8343acfffffffff 83446efffffffff
# USPPS
# 832a13fffffffff
# 8343acfffffffff 832a13fffffffff
# USPS6
# 832742fffffffff
# 8343acfffffffff 832742fffffffff
# not a maritime hex id
# USPTM
# 832af6fffffffff
# 8343acfffffffff 832af6fffffffff
# USPVD
# 832a33fffffffff
# 8343acfffffffff 832a33fffffffff
# USPWM
# 832a34fffffffff
# 8343acfffffffff 832a34fffffffff
# USPWN
# 8344d5fffffffff
# 8343acfffffffff 8344d5fffffffff
# USPYM
# 832a31fffffffff
# 8343acfffffffff 832a31fffffffff
# USRAJ
# 832b89fffffffff
# 8343acfffffffff 832b89fffffffff
# not a maritime hex id
# USRBC
# 8344aefffffffff
# 8343acfffffffff 8344aefffffffff
# USRIC
# 832a8dfffffffff
# 8343acfffffffff 832a8dfffffffff
# USRNO
# USSAC
# 832832fffffffff
# 8343acfffffffff 832832fffffffff
# not a maritime hex id
# USSAN
# 8329a4fffffffff
# 8343acfffffffff 8329a4fffffffff
# USSAT
# USSAV
# 8344d5fffffffff
# 8343acfffffffff 8344d5fffffffff
# USSCK
# 832836fffffffff
# 8343acfffffffff 832836fffffffff
# USSEA
# 8328d5fffffffff
# 8343acfffffffff 8328d5fffffffff
# USSFO
# 832830fffffffff
# 8343acfffffffff 832830fffffffff
# USSLC
# 832696fffffffff
# 8343acfffffffff 832696fffffffff
# not a maritime hex id
# USSPT
# 83262cfffffffff
# 8343acfffffffff 83262cfffffffff
# not a maritime hex id
# USSSI
# 8344f3fffffffff
# 8343acfffffffff 8344f3fffffffff
# USSTL
# 832640fffffffff
# 8343acfffffffff 832640fffffffff
# not a maritime hex id
# USSTP
# 832752fffffffff
# 8343acfffffffff 832752fffffffff
# not a maritime hex id
# USSUE
# 832743fffffffff
# 8343acfffffffff 832743fffffffff
# not a maritime hex id
# USSUW
# 832756fffffffff
# 8343acfffffffff 832756fffffffff
# not a maritime hex id
# USSWF
# 832a16fffffffff
# 8343acfffffffff 832a16fffffffff
# not a maritime hex id
# USSXT
# USSXZ
# 83274dfffffffff
# 8343acfffffffff 83274dfffffffff
# not a maritime hex id
# USTIW
# 8328d5fffffffff
# 8343acfffffffff 8328d5fffffffff
# USTMM
# 832641fffffffff
# 8343acfffffffff 832641fffffffff
# not a maritime hex id
# USTOL
# 832a94fffffffff
# 8343acfffffffff 832a94fffffffff
# not a maritime hex id
# USTPA
# 83441afffffffff
# 8343acfffffffff 83441afffffffff
# USTSA
# 832648fffffffff
# 8343acfffffffff 832648fffffffff
# not a maritime hex id
# USTUL
# 8326eefffffffff
# 8343acfffffffff 8326eefffffffff
# not a maritime hex id
# USUGN
# 832759fffffffff
# 8343acfffffffff 832759fffffffff
# not a maritime hex id
# USUXZ
# 832a10fffffffff
# 8343acfffffffff 832a10fffffffff
# USUZF
# 832b9bfffffffff
# 8343acfffffffff 832b9bfffffffff
# not a maritime hex id
# USVAB
# 832af6fffffffff
# 8343acfffffffff 832af6fffffffff
# USXGO
# 832a10fffffffff
# 8343acfffffffff 832a10fffffffff
# USXHF
# 8328d5fffffffff
# 8343acfffffffff 8328d5fffffffff
# USXHO
# 832a10fffffffff
# 8343acfffffffff 832a10fffffffff
# USYOB
# 8344dafffffffff
# 8343acfffffffff 8344dafffffffff
# not a maritime hex id
# UYCYR
# 83c2d1fffffffff
# 8343acfffffffff 83c2d1fffffffff
# not a maritime hex id
# UYMVD
# 83c2f1fffffffff
# 8343acfffffffff 83c2f1fffffffff
# UYNVP
# 83c2c5fffffffff
# 8343acfffffffff 83c2c5fffffffff
# UYPDU
# 83c2c3fffffffff
# 8343acfffffffff 83c2c3fffffffff
# not a maritime hex id
# VCKTN
# 835e71fffffffff
# 8343acfffffffff 835e71fffffffff
# VEAMY
# 836755fffffffff
# 8343acfffffffff 836755fffffffff
# VEBLA
# 835f49fffffffff
# 8343acfffffffff 835f49fffffffff
# VEEGU
# 835f4bfffffffff
# 8343acfffffffff 835f4bfffffffff
# VEETV
# 83662cfffffffff
# 8343acfffffffff 83662cfffffffff
# VEGUB
# 83e743fffffffff
# 8343acfffffffff 83e743fffffffff
# VEGUT
# 835f49fffffffff
# 8343acfffffffff 835f49fffffffff
# VELAG
# 836741fffffffff
# 8343acfffffffff 836741fffffffff
# VELSV
# 836752fffffffff
# 8343acfffffffff 836752fffffffff
# VEMAR
# 836752fffffffff
# 8343acfffffffff 836752fffffffff
# VEMTV
# 835f41fffffffff
# 8343acfffffffff 835f41fffffffff
# not a maritime hex id
# VEPBL
# 836743fffffffff
# 8343acfffffffff 836743fffffffff
# VEPCN
# 836755fffffffff
# 8343acfffffffff 836755fffffffff
# VEPSU
# 836759fffffffff
# 8343acfffffffff 836759fffffffff
# not a maritime hex id
# VEPZO
# 835f41fffffffff
# 8343acfffffffff 835f41fffffffff
# not a maritime hex id
# VGRAD
# 834ce8fffffffff
# 8343acfffffffff 834ce8fffffffff
# VGTOV
# 834ce8fffffffff
# 8343acfffffffff 834ce8fffffffff
# VICHA
# 834ce8fffffffff
# 8343acfffffffff 834ce8fffffffff
# VICTD
# 834cebfffffffff
# 8343acfffffffff 834cebfffffffff
# VISTT
# 834ce8fffffffff
# 8343acfffffffff 834ce8fffffffff
# VISTX
# 834cebfffffffff
# 8343acfffffffff 834cebfffffffff
# VNCLI
# 8365b5fffffffff
# 8343acfffffffff 8365b5fffffffff
# VNCLN
# 834151fffffffff
# 8343acfffffffff 834151fffffffff
# VNDAD
# 834164fffffffff
# 8343acfffffffff 834164fffffffff
# VNHPH
# 834142fffffffff
# 8343acfffffffff 834142fffffffff
# VNNHA
# 836914fffffffff
# 8343acfffffffff 836914fffffffff
# VNPHG
# 8365b5fffffffff
# 8343acfffffffff 8365b5fffffffff
# VNSGN
# 8365b5fffffffff
# 8343acfffffffff 8365b5fffffffff
# VNSTD
# 8365b4fffffffff
# 8343acfffffffff 8365b4fffffffff
# VNTOT
# 8365b5fffffffff
# 8343acfffffffff 8365b5fffffffff
# VNTTD
# 8365b5fffffffff
# 8343acfffffffff 8365b5fffffffff
# VNUIH
# 836930fffffffff
# 8343acfffffffff 836930fffffffff
# VNVIC
# 8365b5fffffffff
# 8343acfffffffff 8365b5fffffffff
# VNVUT
# 8365b5fffffffff
# 8343acfffffffff 8365b5fffffffff
# VUSON
# 839e02fffffffff
# 8343acfffffffff 839e02fffffffff
# VUVLI
# 839e22fffffffff
# 8343acfffffffff 839e22fffffffff
# WSAPW
# 839a15fffffffff
# 8343acfffffffff 839a15fffffffff
# YEADE
# 8352c6fffffffff
# 8343acfffffffff 8352c6fffffffff
# YEHOD
# 8352f4fffffffff
# 8343acfffffffff 8352f4fffffffff
# YELAD
# 8352c6fffffffff
# 8343acfffffffff 8352c6fffffffff
# YEMKX
# 8352edfffffffff
# 8343acfffffffff 8352edfffffffff
# YTLON
# 83a304fffffffff
# 8343acfffffffff 83a304fffffffff
# ZABFN
# 83bceefffffffff
# 8343acfffffffff 83bceefffffffff
# not a maritime hex id
# ZACPT
# 83ad36fffffffff
# 8343acfffffffff 83ad36fffffffff
# ZADUR
# 83bc1bfffffffff
# 8343acfffffffff 83bc1bfffffffff
# ZAELS
# 83bc09fffffffff
# 8343acfffffffff 83bc09fffffffff
# ZAJNB
# 83bcc3fffffffff
# 8343acfffffffff 83bcc3fffffffff
# not a maritime hex id
# ZAPLZ
# 83bc73fffffffff
# 8343acfffffffff 83bc73fffffffff
# ZAPRY
# 83bcdcfffffffff
# 8343acfffffffff 83bcdcfffffffff
# not a maritime hex id
# ZARCB
# 83bcf4fffffffff
# 8343acfffffffff 83bcf4fffffffff
# ZAZBA
# 83bc73fffffffff
# 8343acfffffffff 83bc73fffffffff
# ZMLUN
# 839623fffffffff
# 8343acfffffffff 839623fffffffff
# not a maritime hex id
# ZWBUQ
# 839772fffffffff
# 8343acfffffffff 839772fffffffff
# not a maritime hex id
# ZWHRE
# 839719fffffffff
# 8343acfffffffff 839719fffffffff
# not a maritime hex id
# ZWUTA
# 839703fffffffff
# 8343acfffffffff 839703fffffffff
# not a maritime hex id

# %%
gdf = gpd.GeoDataFrame(routes)

# %%
with open('routes.geojson' , 'w') as file:
    file.write(gdf.to_json())
